# %%
import requests
from bs4 import BeautifulSoup
URL = 'https://www.monster.com/jobs/search/?q=Programmer&where=india'
page = requests.get(URL)
soup = BeautifulSoup(page.content, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en" xml:lang="en" xmlns="https://www.w3.org/1999/xhtml">
# <head>
# <link href="https://coda.newjobs.com" rel="preconnect"/>
# <link href="https://js-seeker.newjobs.com" rel="preconnect"/>
# <link href="https://css-seeker.newjobs.com" rel="preconnect"/>
# <link href="https://securemedia.newjobs.com" rel="preconnect"/>
# <link href="https://logs2.jobs.com" rel="preconnect"/>
# <link href="https://job-openings.monster.com" rel="preconnect"/>
# <link href="https://apis.google.com" rel="preconnect"/>
# <link href="https://www.google.com" rel="preconnect"/>
# <link href="https://accounts.google.com" rel="preconnect"/>
# <link href="https://content.googleapis.com" rel="preconnect"/>
# <link href="https://ssl.gstatic.com" rel="preconnect"/>
# <link href="https://www.dropbox.com" rel="preconnect"/>
# <link href="http://js.live.net" rel="preconnect"/>
# <link href="https://r.turn.com" rel="preconnect"/>
# <link href="https://www.facebook.com" rel="preconnect"/>
# <link href="https://dpm.demdex.net" rel="preconnect"/>
# <link href="https://monster.demdex.net" rel="preconnect"/>
# <link href="https://fast.monster.demdex.net" rel="preconnect"/>
# <link href="https://logs.jobs.com" rel="preconnect"/>
# <link crossorigin="" href="https://fonts.gstatic.com/" rel="preconnect"/>
# <link crossorigin="" href="https://cdnjs.cloudflare.com/" rel="preconnect"/>
# <link crossorigin="" href="https://netdna.bootstrapcdn.com/" rel="preconnect"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="0" http-equiv="Expires"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=2.0, minimum-scale=1" name="viewport"/>
# <meta content="1" name="j_jp"/>
# <meta charset="utf-8"/>
# <title>Programmer Jobs in Johnstown, PA. Johnstown Programmer Jobs | Monster.com</title>
# <style type="text/css">
#                 @font-face{font-family:'Roboto';font-style:normal;font-weight:100;font-display:optional;src:local('Roboto Thin'),local('Roboto-Thin'),local('sans-serif-thin'),url(https://fonts.gstatic.com/s/roboto/v19/KFOkCnqEu92Fr1MmgVxFIzIXKMnyrYk.woff2) format('woff2');unicode-range:U+0460-052F,U+1C80-1C88,U+20B4,U+2DE0-2DFF,U+A640-A69F,U+FE2E-FE2F}@font-face{font-family:'Roboto';font-style:normal;font-weight:100;font-display:optional;src:local('Roboto Thin'),local('Roboto-Thin'),local('sans-serif-thin'),url(https://fonts.gstatic.com/s/roboto/v19/KFOkCnqEu92Fr1MmgVxMIzIXKMnyrYk.woff2) format('woff2');unicode-range:U+0400-045F,U+0490-0491,U+04B0-04B1,U+2116}@font-face{font-family:'Roboto';font-style:normal;font-weight:100;font-display:optional;src:local('Roboto Thin'),local('Roboto-Thin'),local('sans-serif-thin'),url(https://fonts.gstatic.com/s/roboto/v19/KFOkCnqEu92Fr1MmgVxEIzIXKMnyrYk.woff2) format('woff2');unicode-range:U+1F00-1FFF}@font-face{font-family:'Roboto';font-style:normal;font-weight:100;font-display:optional;src:local('Roboto Thin'),local('Roboto-Thin'),local('sans-serif-thin'),url(https://fonts.gstatic.com/s/roboto/v19/KFOkCnqEu92Fr1MmgVxLIzIXKMnyrYk.woff2) format('woff2');unicode-range:U+0370-03FF}@font-face{font-family:'Roboto';font-style:normal;font-weight:100;font-display:optional;src:local('Roboto Thin'),local('Roboto-Thin'),local('sans-serif-thin'),url(https://fonts.gstatic.com/s/roboto/v19/KFOkCnqEu92Fr1MmgVxHIzIXKMnyrYk.woff2) format('woff2');unicode-range:U+0102-0103,U+0110-0111,U+1EA0-1EF9,U+20AB}@font-face{font-family:'Roboto';font-style:normal;font-weight:100;font-display:optional;src:local('Roboto Thin'),local('Roboto-Thin'),local('sans-serif-thin'),url(https://fonts.gstatic.com/s/roboto/v19/KFOkCnqEu92Fr1MmgVxGIzIXKMnyrYk.woff2) format('woff2');unicode-range:U+0100-024F,U+0259,U+1E00-1EFF,U+2020,U+20A0-20AB,U+20AD-20CF,U+2113,U+2C60-2C7F,U+A720-A7FF}@font-face{font-family:'Roboto';font-style:normal;font-weight:100;font-display:optional;src:local('Roboto Thin'),local('Roboto-Thin'),local('sans-serif-thin'),url(https://fonts.gstatic.com/s/roboto/v19/KFOkCnqEu92Fr1MmgVxIIzIXKMny.woff2) format('woff2');unicode-range:U+0000-00FF,U+0131,U+0152-0153,U+02BB-02BC,U+02C6,U+02DA,U+02DC,U+2000-206F,U+2074,U+20AC,U+2122,U+2191,U+2193,U+2212,U+2215,U+FEFF,U+FFFD}@font-face{font-family:'Roboto';font-style:normal;font-weight:300;font-display:optional;src:local('Roboto Light'),local('Roboto-Light'),local('sans-serif-light'),url(https://fonts.gstatic.com/s/roboto/v19/KFOlCnqEu92Fr1MmSU5fCRc4AMP6lbBP.woff2) format('woff2');unicode-range:U+0460-052F,U+1C80-1C88,U+20B4,U+2DE0-2DFF,U+A640-A69F,U+FE2E-FE2F}@font-face{font-family:'Roboto';font-style:normal;font-weight:300;font-display:optional;src:local('Roboto Light'),local('Roboto-Light'),local('sans-serif-light'),url(https://fonts.gstatic.com/s/roboto/v19/KFOlCnqEu92Fr1MmSU5fABc4AMP6lbBP.woff2) format('woff2');unicode-range:U+0400-045F,U+0490-0491,U+04B0-04B1,U+2116}@font-face{font-family:'Roboto';font-style:normal;font-weight:300;font-display:optional;src:local('Roboto Light'),local('Roboto-Light'),local('sans-serif-light'),url(https://fonts.gstatic.com/s/roboto/v19/KFOlCnqEu92Fr1MmSU5fCBc4AMP6lbBP.woff2) format('woff2');unicode-range:U+1F00-1FFF}@font-face{font-family:'Roboto';font-style:normal;font-weight:300;font-display:optional;src:local('Roboto Light'),local('Roboto-Light'),local('sans-serif-light'),url(https://fonts.gstatic.com/s/roboto/v19/KFOlCnqEu92Fr1MmSU5fBxc4AMP6lbBP.woff2) format('woff2');unicode-range:U+0370-03FF}@font-face{font-family:'Roboto';font-style:normal;font-weight:300;font-display:optional;src:local('Roboto Light'),local('Roboto-Light'),local('sans-serif-light'),url(https://fonts.gstatic.com/s/roboto/v19/KFOlCnqEu92Fr1MmSU5fCxc4AMP6lbBP.woff2) format('woff2');unicode-range:U+0102-0103,U+0110-0111,U+1EA0-1EF9,U+20AB}@font-face{font-family:'Roboto';font-style:normal;font-weight:300;font-display:optional;src:local('Roboto Light'),local('Roboto-L ...
#         </style>
# <style type="text/css">
#
#
# @font-face{font-family:"Material Design Icons";src:url("https://securemedia.newjobs.com/global/fonts/materialdesignicons-1.9.32/materialdesignicons-webfont.eot?v=1.9.32");src:url("https://securemedia.newjobs.com/global/fonts/materialdesignicons-1.9.32/materialdesignicons-webfont.eot?#iefix&v=1.9.32") format("embedded-opentype"),url("https://securemedia.newjobs.com/global/fonts/materialdesignicons-1.9.32/materialdesignicons-webfont.woff2?v=1.9.32") format("woff2"),url("https://securemedia.newjobs.com/global/fonts/materialdesignicons-1.9.32/materialdesignicons-webfont.woff?v=1.9.32") format("woff"),url("https://securemedia.newjobs.com/global/fonts/materialdesignicons-1.9.32/materialdesignicons-webfont.ttf?v=1.9.32") format("truetype"),url("https://securemedia.newjobs.com/global/fonts/materialdesignicons-1.9.32/materialdesignicons-webfont.svg?v=1.9.32#materialdesigniconsregular") format("svg");font-weight:400;font-style:normal;font-display:swap;}.mdi::before{display:inline-block;font-style:normal;font-variant:normal;font-weight:400;font-family:'Material Design Icons';font-size:inherit;text-rendering:auto;line-height:inherit;-webkit-font-smoothing:antialiased}.mdi-magnify::before{content:"\f349"}.mdi-map-marker::before{content:"\f34e"}html{font-family:sans-serif}body{margin:0}header,main,nav,section{display:block}a{background-position:0 0;background-repeat:initial initial}h1{font-size:2em;margin:.67em 0}button,input,select{color:inherit;font-family:inherit;font-size:inherit;font-style:inherit;font-variant:inherit;font-weight:inherit;line-height:inherit;margin:0}button{overflow:visible}button,select{text-transform:none}button{-webkit-appearance:button}input{line-height:normal}input[type="checkbox"]{box-sizing:border-box;padding:0}*{box-sizing:border-box}::before,::after{box-sizing:border-box}html{font-size:62.5%}body{font-family:'Helvetica Neue',Helvetica,Arial,sans-serif;font-size:14px;line-height:1.42857143;color:rgb(51,51,51);background-color:rgb(255,255,255)}input,button,select{font-family:inherit;font-size:inherit;line-height:inherit}a{color:rgb(66,139,202);text-decoration:none}.sr-only{position:absolute;width:1px;height:1px;margin:-1px;padding:0;overflow:hidden;clip:rect(0 0 0 0);border:0}h1,h2,h3,h4{font-family:inherit;font-weight:500;line-height:1.1;color:inherit}h1,h2,h3{margin-top:20px;margin-bottom:10px}h4{margin-top:10px;margin-bottom:10px}h1{font-size:36px}h2{font-size:30px}h3{font-size:24px}h4{font-size:18px}p{margin:0 0 10px}.lead{margin-bottom:20px;font-size:16px;font-weight:200;line-height:1.4}@media (min-width:768px){.lead{font-size:21px}}.text-center{text-align:center}ul{margin-top:0;margin-bottom:10px}ul ul{margin-bottom:0}.list-inline{padding-left:0;list-style:none;margin-left:-5px}.container{margin-right:auto;margin-left:auto;padding-left:15px;padding-right:15px}@media (min-width:768px){.container{width:750px}}@media (min-width:992px){.container{width:970px}}@media (min-width:1200px){.container{width:1170px}}.container-fluid{margin-right:auto;margin-left:auto;padding-left:15px;padding-right:15px}.row{margin-left:-15px;margin-right:-15px}.col-md-4,.col-sm-6,.col-md-8{position:relative;min-height:1px;padding-left:15px;padding-right:15px}@media (min-width:768px){.col-sm-6{float:left}.col-sm-6{width:50%}}@media (min-width:992px){.col-md-4,.col-md-8{float:left}.col-md-8{width:66.66666667%}.col-md-4{width:33.33333333%}}label{display:inline-block;margin-bottom:5px;font-weight:700}input[type="checkbox"]{margin:4px 0 0;line-height:normal}.form-control{display:block;width:100%;height:34px;padding:6px 12px;font-size:14px;line-height:1.42857143;color:rgb(85,85,85);background-color:rgb(255,255,255);background-image:none;border:1px solid rgb(204,204,204);border-top-left-radius:4px;border-top-right-radius:4px;border-bottom-right-radius:4px;border-bottom-left-radius:4px;-webkit-box-shadow:rgba(0,0,0,.0745098) 0 1px 1px inset;box-shadow:rgba(0,0,0,.0745098) 0 1px 1px inset}.form-control::-webkit-input-placeholder{color:rgb(153 ...
#
# .mux-job-cards [class*=col-].inverse-colors {
#     background-color: #6E46AE;
#     color: #fff;
# }
#
# #policy-top.widget.popup-widget{background:#E6852B;width:852px;position:fixed;top:-120px;left:50%;margin-left:-410px;padding:0;z-index:1030;border:0;box-shadow:0 2px 12px rgba(0,0,0,.2);transition:.5s}#policy-top.widget.popup-widget.reveal{top:148px;transition:.5s}#policy-top.widget.popup-widget .widget-head{color:#fff;border:0;border-bottom:1px solid rgba(255,255,255,.26);border-radius:0;padding:8px 15px 9px}#policy-top.widget.popup-widget .widget-head .fa{width:30px;padding-right:12px;display:table-cell;vertical-align:top}#policy-top.widget.popup-widget .widget-content{color:#fff;background:none;padding:0 15px 1px}#policy-top.widget.popup-widget .widget-content h5{color:#fff;font-weight:500}#policy-top.widget.popup-widget .marked-title{width:98%;display:table}#policy-top.widget.popup-widget .marked-title h5,#policy-top.widget.popup-widget .marked-title .h5{color:#fff;text-shadow:none;display:table-cell;padding-top:2px}#policy-top .form-control{font-weight:400;height:40px;color:#212121;border-color:#bdbdbd;border-color:rgba(0,0,0,.26)}#policy-top.widget.popup-widget .form-control{width:350px;margin-right:4px;border:0;display:inline-block}#policy-top.widget.widget-head.widget-content h5{color:#fff;nt-weight:400;text-shadow:none}#policy-top.save_search_header{font-size:14px;font-weight:400;line-height:24px;margin-bottom:9px;display:block}#policy-top.widget.popup-widget .savedSearches h5{font-weight:300;text-shadow:none;color:#fff}#policy-top.widget.popup-widget .savedSearches h5 a{font-weight:300;text-shadow:none;text-decoration:underline;color:#fff}#policy-top.widget.popup-widget .savedSearchesstrong{font-weight:600}#policy-top.widget.popup-widget .close-icon{position:absolute;padding:8px;right:0;top:0;font-size:20px;color:#8ADAF8;color:rgba(255,255,255,.54);cursor:pointer}#policy-top.widget.popup-widget .close-icon:hover{color:#DEF5FD;color:rgba(255,255,255,.87)}#policy-top.widget.popup-widget .close-icon{margin-top:5px;position:absolute;padding:8px;right:0;top:0;font-size:20px;color:#8ADAF8;color:rgba(255,255,255,.54);cursor:pointer}#policy-top.widget.popup-widget .close-icon:hover{color:#DEF5FD;color:rgba(255,255,255,.87)}@media (max-width:767px){#policy-top.widget.popup-widget{width:300px;top:-350px;margin-left:-154px;margin-top:89px}#policy-top.widget.popup-widget.reveal{top:74px}#policy-top.widget.popup-widget .form-control{width:100%;display:block}#policy-top.widget.popup-widget .emailButtonModalPopup{width:100%;display:block}#policy-top .litRegPrivacy{display:block}#policy-top.widget.popup-widget.error-state .error-box{margin-top:0;margin-bottom:12px}#policy-top .label--checkbox{margin-left:0;margin-top:4px}}
#     </style>
# <!--[if IE 8]>
#       <link rel="stylesheet" type="text/css" href="https://securemedia.newjobs.com/niche/css/generic-template/style-ie.css" />
# <![endif]-->
# <!--[if lt IE 9]>
# <script src="https://securemedia.newjobs.com/niche/js/html5shim.js"></script>
# <script src="/siteassets/scripts/respond.js" type="text/javascript"></script>
# <![endif]-->
# <link href="https://www.monster.com/jobs/search/?q=Programmer&amp;where=india" rel="canonical"/>
# <link href="https://securemedia.newjobs.com/favicon.ico" id="favIcon" rel="shortcut icon" runat="server"/>
# <meta content="Explore Johnstown, india Programmer jobs and career resources on Monster. Find all the information you need to land a Programmer job in Johnstown, india and build a career." name="description">
# <meta content="Johnstown india Programmer jobs, Johnstown india Programmer career resources, Johnstown india Programmer careers, Johnstown india Programmer job, Johnstown india Programmer career, Johnstown india Programmer employment, Johnstown india Programmer work, Johnstown india Programmer job opportunities, Johnstown india Programmer employment opportunities" name="keywords"/>
# <meta content="login.monster.com" name="SL.domain"/>
# <meta content="MONS" name="SL.channelAlias"/>
# <meta content="Programmer Jobs in Johnstown, PA. Johnstown Programmer Jobs | Monster.com" property="og:title"/>
# <meta content="website" property="og:type"/>
# <meta content="https://www.monster.com/jobs/search/?q=Programmer&amp;where=india" property="og:url"/>
# <meta content="https://securemedia.newjobs.com/id/lpf20/CORE/icon-50-m.png" property="og:image"/>
# <meta content="Monster" property="og:site_name"/>
# <meta content="Explore Johnstown, india Programmer jobs and career resources on Monster. Find all the information you need to land a Programmer job in Johnstown, india and build a career." property="og:description"/>
# <meta content="Programmer Jobs in Johnstown, PA. Johnstown Programmer Jobs | Monster.com" itemprop="name"/>
# <meta content="Explore Johnstown, india Programmer jobs and career resources on Monster. Find all the information you need to land a Programmer job in Johnstown, india and build a career." itemprop="description"/>
# <meta content="https://securemedia.newjobs.com/id/lpf20/CORE/icon-50-m.png" itemprop="image"/>
# <meta content="Site=United States&amp;mURL=http://www.monster.com/search/?q=Programmer&amp;where=india&amp;lid=584" name="OAS_query"/>
# <link href="https://www.monster.com/jobs/search/?page=2" rel="next"/>
# <script>
#         window.MONS_LOCALES = {
#             coda: {
#                 images: 'https://coda.newjobs.com/Assets/MUX/JaJobViewCloud/2020.05.0.765/img/'
#             }
#         }
#         window.onMsgsReady = function (msgs) {
#             window.MONS_LOCALES.msg = msgs;
#     };
# </script>
# <script defer="" src="https://logs.jobs.com/coreTrackFP" type="text/javascript"></script>
# <script defer="" src="https://logs.jobs.com/coreTrack" type="text/javascript"></script>
# <script defer="" src="https://js-seeker.newjobs.com/MONS/v4.1.2.6/ps.deferload.coretrack_js.axd?s=1" type="text/javascript"></script>
# <script defer="" src="https://coda.newjobs.com/Assets/MUX/CoreLpf20/2020.04.0.174/msgset;MONS/app.lpf20.ids?callback=onMsgsReady" type="text/javascript"></script>
# <script data-locales="https://coda.newjobs.com/Assets/MUX/JaJobViewCloud/2020.05.0.765/msgset;MONS/app.js30.ids" defer="" id="AppJs30" src="https://coda.newjobs.com/Assets/MUX/JaJobViewCloud/2020.05.0.765/js/app.js30.bundle.js" type="text/javascript"></script>
# <script data-locales="https://coda.newjobs.com/Assets/MUX/CoreLpf20/2020.04.0.174/msgset;MONS/app.lpf20.ids" defer="" id="AppLpf20" src="https://coda.newjobs.com/Assets/MUX/CoreLpf20/2020.04.0.174/js/app.lpf20.bundle.js" type="text/javascript"></script>
# <link href="https://css-seeker.newjobs.com/MONS/v4.1.2.11/js30.hybridviewdesk_css.axd?s=1" media="none" onload="if(media!='all')media='all'" rel="stylesheet" type="text/css"/>
# <noscript><link href="https://css-seeker.newjobs.com/MONS/v4.1.2.11/js30.hybridviewdesk_css.axd?s=1" rel="stylesheet"/></noscript>
# <link href="https://css-seeker.newjobs.com/MONS/v4.1.2.8/js30.global.responsive_css.axd?s=1" media="none" onload="if(media!='all')media='all'" rel="stylesheet" type="text/css">
# <noscript><link href="https://css-seeker.newjobs.com/MONS/v4.1.2.8/js30.global.responsive_css.axd?s=1" rel="stylesheet"/></noscript>
# <script defer="" src="https://js-seeker.newjobs.com/MONS/v4.1.2.10/js30.hybridview_js.axd?s=1" type="text/javascript"></script>
# <script type="application/ld+json">
#     {
#     "@context" : "http://schema.org",
#     "@type" : "Organization",
#     "name" : "Monster",
#     "url" : "https://www.monster.com/jobs/search/?q=Programmer&amp;where=india",
#     "logo" : "https://media.newjobs.com/global/img/header-m.png",
#     "sameAs" : [ "https://twitter.com/Monster", "https://www.facebook.com/monster", "https://plus.google.com/+monster", "https://www.youtube.com/monster", "https://instagram.com/monster"]
#     }
# </script>
# <script>
#             //Collect all document ready function or handler and put it in queue where it will be executed once the Jquery is loaded
#             (function (w, d, u) {
#                 w.readyQ = [];
#                 w.bindReadyQ = [];
#                 w.loadQ = [];
#                 w.bindLoadQ = [];
#
#                 function p(x, y) {
#                     if (x == "ready") {
#                         w.bindReadyQ.push(y);
#                     } else {
#                         w.readyQ.push(x);
#                     }
#                 };
#                 function q(x, y) {
#                     if (x == "load") {
#                         w.bindLoadQ.push(y);
#                     } else {
#                         w.loadQ.push(x);
#                     }
#                 };
#                 var a = {
#                     ready: p,
#                     bind: p
#                 };
#                 var b = {
#                     load: q,
#                     bind: q
#                 };
#                 w.$ = w.jQuery = function (f) {
#                     if (f === d || f === u) {
#                         return a
#                     }
#                     else if (f === w) {
#                         return b
#                     } else {
#                         p(f)
#                     }
#                 }
#             })(window, document)
#         </script>
# <meta content="Monster" name="m_impr.a_affiliate_id"/><meta content="q=Programmer&amp;brd=1&amp;brd=2&amp;cy=US&amp;pp=25&amp;sort=rv.di.dt&amp;nosal=true&amp;geo=india%2c32.18688%2c1303764%2c1008805%2c584%2cCity&amp;stp=ScoreFenceHash" name="m_impr.s_search_query"/>
# <meta content="Programmer" name="m_impr.s_q"/>
# <meta content="Johnstown" name="m_impr.s_where"/>
# <meta content="1" name="m_impr.j_pg"/>
# <script defer="" src="//nexus.ensighten.com/monster/limited_prod/Bootstrap.js" type="text/javascript"></script>
# <meta content="
# " name="debugInfo"/>
# <script type="text/javascript">
#        var inHeadTS = (new Date()).getTime();
#     </script>
# </link></meta></head>
# <body class="serp" data-apply-confirmation-info-url="//job-openings.monster.com/v2/job/json-applyconfirmation?Js30Flow=1" data-duplicate-apply-for-job-msg="Already applied to this job with this resume." data-event="jobApplyCompleteEvent" data-list-switch="#ListSwitch" data-login-alert="Welcome back{firstName}, press Apply Now to start your application at the employer's site." data-mux="serp" data-new-user-account-msg="Welcome! Your Monster account has been created; check your email for additional information." data-report-job-msg="Your report has been received. We appreciate your help in identifying issues on our site." data-signup-alert="Welcome{firstName}, press Apply Now to start your application at the employer's site." data-user-firstname="">
# <script defer="" src="https://js-seeker.newjobs.com/MONS/v4.1.2.8/ps.deferload.atm_js.axd?s=1" type="text/javascript"></script>
# <script type="text/javascript">
#             //<![CDATA[
#             var amc=amc||{};if(!amc.on){amc.on=amc.call=function(){}};
#             document.write("<scr" + "ipt defer type='text/javascript' src='https:///securemedia.newjobs.com/js/sc/sitecatalystLL.js'></sc" + "ript>");
#             //]]>
# </script>
# <input id="atm_var" type="hidden" value='{"AccountName":"newjobsProdSeekerUS","AppConfig":{"AppID":"lpf","ChannelID":"58","CountryID":"164","Version":"0"},"AppID":"lpf","ChannelID":58,"CountryID":164,"CurrencyCode":"USD","InitFromOnReady":false,"PageName":"desktop|mons|lpf|jobsearch-trovix-cloud","Properties":"%7b+%22eVar2%22%3a%22unrecognized%22%2c%22channel%22%3a%2258%22%2c%22eVar1%22%3a%22D%3dg%22%2c%22prop1%22%3a%22D%3dg%22%2c%22eVar4%22%3a%220%22%2c%22eVar17%22%3a%22india%22%2c%22eVar16%22%3a%22trovix-cloud%22%2c%22eVar23%22%3a%2238%22%2c%22eVar19%22%3a%22Programmer%22%2c%22eVar24%22%3a%221%22%2c%22eVar18%22%3a%22Unspecified%22%2c%22events.event1%22%3a%22jobsearch%22%2c%22eVar20%22%3a%22Unspecified%22%2c%22list2%22%3a%22Unspecified%22%2c%22list1%22%3a%22Unspecified%22%2c%22eVar21%22%3a%22Unspecified%22%2c%22prop16%22%3a%22Unspecified%22%2c%22prop17%22%3a%22Unspecified%22%2c%22prop18%22%3a%22Unspecified%22%2c%22prop19%22%3a%22Unspecified%22%2c%22eVar22%22%3a%22Unspecified%22%2c%22events.event27%22%3a%22true%22%2c%22eVar73%22%3a%22bolded-0_logo-2_bolded-logo-0_regular-23%22%2c%22list3%22%3a%22ViewSplit_NewCardView%2cEmptySearchSplit_Default%2cBAMLiteSplit_BamLite%2cQualifyingTagsSplit_Control%2cTypeaheadElasticSearchSplit_NewElasticSearch%2cSalaryDisplaySplit_Default%2cSavedJobsSplit_Default%2cJobSearchJobViewHybridSplit_JobSearchJobViewHybridView%2cJobSearchJobViewPureSplit_JobSearchJobViewPureView%2cAdsSplit_Default%2cSsrStateExcludeSplit_SsrStateExcludeEnable%2cBrandingCompanyLogoSplit_BrandingCompLogo%2cJVLoadNonJobContentSplit_JvNonJobContentWithUX%2cSsrRestrictKwdParamSplit_SsrRestrictKwdParamEnable%2cJobSearchFencedEnableSplit_Default%2cFitIconScoreCardSplit_Default%22%2c%22eVar43%22%3a%22Cloud+Search+Y%22+%7d","RegisteredConfigs":null,"RunOnLoad":true,"Version":"0"}'/>
# <div style="display:none;"></div>
# <script defer="" src="https://js-seeker.newjobs.com/MONS/v4.1.2.28/ps.deferload_js.axd?s=1" type="text/javascript"></script>
# <div class="page-layout">
# <div id="headerWidget">
# <input id="AcceptCookies" type="hidden" value="True"/>
# <input id="lpfDomainPath" type="hidden" value="https://www.monster.com/jobs"/>
# <input id="servicesDomainPath" type="hidden" value="https://www.monster.com/jobs"/>
# <input id="inboxLink" type="hidden" value="https://www.monster.com/message/inbox"/>
# <input id="countryId" type="hidden" value="164"/>
# <input id="showLocationTypeAheadTrovix" type="hidden" value="True"/>
# <input id="showLocationTypeAheadLucene" type="hidden" value="False"/>
# <input id="showKeywordTypeAheadTrovix" type="hidden" value="True"/>
# <input id="isLoggedIn" type="hidden" value="False"/>
# <input id="isOnlyRecognized" type="hidden" value="False"/>
# <input id="successMessage" type="hidden" value="You have no new messages."/>
# <input id="cookieName" type="hidden" value="hdCookiesIM"/>
# <input id="cookieValue" type="hidden" value="0"/>
# <input id="cookieExpirationTime" type="hidden" value="365"/>
# <input id="cookieDomain" type="hidden" value=".monster.com"/>
# <input id="searchPageAction" type="hidden" value="https://www.monster.com/jobs/search/"/>
# <input class="mc-mail-box" id="mcMainBox" type="hidden" value=""/>
# <input id="mcAwsUrl" type="hidden" value=""/>
# <input id="countryCode" type="hidden" value="US"/>
# <input id="languageCode" type="hidden" value="EN"/>
# <input id="typeAheadRequestUrl" type="hidden" value="https://c6v0t0t861.execute-api.us-east-1.amazonaws.com/Prod/vulcantypeaheadresource?matchString=%Q&amp;countrycode={0}&amp;languagecode={1}&amp;fuzziness=0"/>
# <input id="esTypeaheadEnabled" type="hidden" value="True"/>
# <input id="msgKeywords" type="hidden" value="Key Words"/>
# <input id="msgJobTitles" type="hidden" value="Job Titles"/>
# <input id="msgCompanyNames" type="hidden" value="Company Names"/>
# <input id="isRedirectionToNoCriteriaPageEnabled" type="hidden" value="true"/>
# <input id="noCriteriaPagePrefix" type="hidden" value="nocriteria"/>
# <input id="accountTitle" type="hidden" value=""/>
# <input id="searchKeyword" type="hidden" value="Programmer"/>
# <input id="searchLocation" type="hidden" value="india"/>
# <input id="companyTAHeaderSearchSelection" type="hidden"/>
# <input id="companyTASearchEnabled" type="hidden" value="False"/>
# <input id="companyTASearchLimit" type="hidden" value="3"/>
# <input id="isTransitionalGlobalHeaderEnabled" type="hidden" value="True"/>
# <div id="pv_nav-fixed">
# <a class="skip-main" href="#mainContent">Skip to main content</a>
# <!-- Top Nav -->
# <nav class="solid-nav navbar-2 navbar navbar-default navbar-fixed-top" id="jsrHeader" role="banner">
# <div class="container-fluid navbar-main">
# <!-- Brand and toggle get grouped for better mobile display -->
# <div class="navbar-header" id="mobile-navbar">
# <a aria-label="Monster Home" class="navbar-brand" href="https://www.monster.com/">
# <div class="logo-new-branding-g-header" style="background-image:url( https://media.newjobs.com/global/img/monster-logo-h-teal.svg )"> </div>
# </a>
# <button aria-expanded="false" aria-haspopup="true" class="navbar-toggle nav-trigger action action--open" data-target-menu="ml-menu" role="menu" type="button">
# <span class="sr-only">Toggle Navigation Mobile</span>
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# </button>
# <button aria-expanded="false" aria-haspopup="true" class="navbar-toggle search-btn-container search-trigger" data-target="#mobile-navbar-search" data-toggle="collapse" role="search" type="button">
# <i class="fa fa-search"></i>
# <span class="navbar-text">Jobs</span>
# </button>
# <!-- End Search Button -->
# </div>
# <!-- End Mobile Header/Navbar -->
# <div class="collapse navbar-collapse text-center" id="mobile-navbar-search" style="max-height: 423px;">
# <!-- End Navbar Right, Login, Signup, & Employer Links -->
# <form class="navbar-form" id="quickJobSearch" method="get" role="search">
# <div class="form-group top-search keywords rounded-border">
# <div class="input-group input-group-sm">
# <span class="input-group-addon"><i class="mdi mdi-magnify"></i></span>
# <div id="multiple-datasets">
# <label class="sr-only" for="keywords2">Keywords</label>
# <input aria-autocomplete="both" aria-expanded="false" class="form-control typeaheadR tt-hint hasclear" id="keywords2" name="q" placeholder="Search for Jobs" role="combobox" type="text" value="Programmer"/>
# <input id="typeaheadvalues" type="hidden" value=""/>
# </div>
# <span aria-label="clear" class="input-clear" style="" tabindex="0">x</span>
# </div>
# </div>
# <div class="form-group top-search location rounded-border">
# <div class="input-group input-group-sm">
# <span class="input-group-addon"><i class="mdi mdi-map-marker"></i></span>
# <label class="sr-only" for="location">Location</label>
# <input aria-autocomplete="both" aria-expanded="false" autocomplete="off" class="form-control input-sm typeahead hasclear" id="location" name="where" placeholder="Location" role="combobox" type="text" value="india"/>
# <span aria-label="clear" class="input-clear" style="" tabindex="0">x</span>
# </div>
# </div>
# <button class="btn btn-white btn-sm rounded-border" id="doQuickSearch" onclick="InitializeGlobalheaderSearch(); return false;" type="button">Search</button>
# <div class="tm-wrap">
# <input class="tm-input hidden" maxlength="200" type="hidden"/>
# </div>
# </form>
# <!-- End Search Form (Desktop & Mobile) -->
# <ul class="nav navbar-nav navbar-right hidden-xs">
# <li>
# <a aria-expanded="false" aria-haspopup="true" class="navbar-icon-link loginLink1" href="https://login20.monster.com/?r=http%3a%2f%2fjobs.monster.com%2fsearch%2f%3fq%3dProgrammer%26where%3dindia&amp;ch=MONS" role="button">
# <span>Sign In</span>
# </a>
# </li>
# <li>
# <a aria-expanded="false" aria-haspopup="true" class="navbar-icon-link loginLink2" href="https://hiring.monster.com/?intcid=skr_LPF_TopNav_Employer&amp;ch=MONS" role="button">
# <span>For Employers</span>
# </a>
# </li>
# </ul>
# </div>
# </div>
# <div class="container-fluid subnav top-subnav hidden-xs bg-new" role="navigation">
# <ul class="nav navbar-nav hidden-xs subnav-nav clearfix">
# <li class="dropdown" id="main-nav-0">
# <a aria-expanded="false" aria-haspopup="true" class="dropdown-toggle" data-toggle="dropdown" href="#" role="button">
#                                     Find Jobs <span class="caret"></span>
# </a>
# <ul class="dropdown-menu">
# <li id="sub-nav-0">
# <a href="https://www.monster.com/jobs/">Browse Jobs</a>
# </li>
# <li id="sub-nav-1">
# <a href="https://www.monster.com/jobs/advanced-search/">Advanced Search</a>
# </li>
# </ul>
# </li>
# <li class="dropdown" id="main-nav-1">
# <a class="dropdown-toggle" href="https://www.monster.com/resumes/post-resume?landedFrom=Header">Upload Resume</a>
# </li>
# <li class="dropdown" id="main-nav-2">
# <a class="dropdown-toggle" href="https://www.monster.com/salary">Salary Tools</a>
# </li>
# <li class="dropdown" id="main-nav-3">
# <a class="dropdown-toggle" href="https://www.monster.com/resumes/writing-services">Resume Help</a>
# </li>
# <li class="dropdown" id="main-nav-4">
# <a class="dropdown-toggle" href="https://www.monster.com/career-advice">Career Advice</a>
# </li>
# </ul>
# </div>
# <!-- End Main Nav or "Subnav" (Desktop)-->
# <!-- Slideout Menu Container -->
# <div class="container">
# </div>
# <!-- End Main Container for Mobile Main Nav -->
# <!-- Main container -->
# <div class="container">
# <!-- Menu -->
# <!-- Mobile Left Nav -->
# <nav class="menu" id="ml-menu">
# <!-- Close button for mobile version -->
# <button aria-label="Close Menu" class="action action--close">×</button>
# <!-- Edit contents of Init Crumb 1 to edit first breadcrumb in left slidout menu. -->
# <!-- Menu contents. -->
# <div class="menu__wrap" id="ml-menu-container">
# <ul class="menu__level menu__level--current" data-menu="main">
# <li class="menu__item" id="mobile-nav-2">
# <a class="menu__link" href="https://login20.monster.com/?r=http%3a%2f%2fjobs.monster.com%2fsearch%2f%3fq%3dProgrammer%26where%3dindia&amp;ch=MONS" role="menuitem">Sign In</a>
# </li>
# <li class="divider" role="separator"></li>
# <li class="menu__item" id="mobile-nav-0">
# <a aria-expanded="false" aria-haspopup="true" class="menu__link" data-submenu="submenu-0" href="#" role="menuitem">Find Jobs</a>
# <ul class="menu__level" data-menu="submenu-0">
# <li class="menu__item" id="mobile-subnav-2">
# <a class="menu__link bold-submenu" href="#" role="menuitem">Find Jobs</a>
# </li>
# <li class="menu__item" id="mobile-subnav-3">
# <a class="menu__link" href="https://www.monster.com/jobs/" role="menuitem">Browse Jobs</a>
# </li>
# <li class="menu__item" id="mobile-subnav-4">
# <a class="menu__link" href="https://www.monster.com/jobs/advanced-search/" role="menuitem">Advanced Search</a>
# </li>
# </ul>
# </li>
# <li class="menu__item" id="mobile-nav-1">
# <a class="menu__link" href="https://www.monster.com/resumes/post-resume?landedFrom=Header" role="menuitem">Upload Resume</a>
# </li>
# <li class="menu__item" id="mobile-nav-2">
# <a class="menu__link" href="https://www.monster.com/salary" role="menuitem">Salary Tools</a>
# </li>
# <li class="menu__item" id="mobile-nav-3">
# <a class="menu__link" href="https://www.monster.com/resumes/writing-services" role="menuitem">Resume Help</a>
# </li>
# <li class="menu__item" id="mobile-nav-4">
# <a class="menu__link" href="https://www.monster.com/career-advice" role="menuitem">Career Advice</a>
# </li>
# <li class="divider" role="separator"></li>
# <li class="menu__item" id="mobile-nav-2">
# <a class="menu__link" href="https://hiring.monster.com/?intcid=skr_LPF_TopNav_Employer&amp;ch=MONS" role="menuitem">For Employers</a>
# </li>
# </ul>
# </div>
# </nav>
# </div>
# <!-- End Main Container for Mobile Main Nav -->
# </nav>
# <!-- End Navbar Fixed Top -->
# </div>
# <script type="text/javascript">
#         //Needed for defer loaded jquery to initialize when jQuery finish loaded
#         var initInterval = setInterval(function () {
#             if (window.jQuery) {
#                 clearInterval(initInterval);
#                 init();
#             }
#         }, 20);
#
#         function init() {
# 			$(document).ready(function () {
#
#                 $('li.twocolumnslink > a').on('click',
#                     function (event) {
#                         var parentLi = $(this).parent();
#
#                         if ($(this).parent().attr('class').indexOf("twocolumnslink-close") != -1) {
#                             parentLi.removeClass('twocolumnslink-close').addClass('twocolumnslink-open');
#                         } else {
#                             parentLi.removeClass('twocolumnslink-open').addClass('twocolumnslink-close');
#                         }
#                     });
#
#                 //Sub-Menu Mobile
#                 var $mlSubMenus = $('#ml-menu-container ul[data-menu*="submenu-"]');
#                 if ($mlSubMenus.length) {
#                     $mlSubMenus.each(function () {
#                         $(this).appendTo('#ml-menu-container');
#                     });
#                 }
#
#                 //CMS Desktop
#                 var $cmsNavContainers = $("li[id*='main-nav-'] div.cmsNavContainer");
#                 if ($cmsNavContainers.length) {
#                     for (var i = 0; i < $cmsNavContainers.length; i++) {
#                         var $this = $($cmsNavContainers[i]);
#                         $this.addClass('hidden');
#                         var title = $this.find('h3').html();
#                         var $childs = $this.find('ul li');
#
#                         var $parentUl = $this.closest('ul');
#                         $parentUl.append('<li class="cmsNavContainer dropdown-sub"></li>');
#                         var $newCmsContainer = $parentUl.find('li.cmsNavContainer.dropdown-sub');
#                         $newCmsContainer.append('<a href="#" class="dropdown-toggle" data-toggle="dropdown" role="button" aria-haspopup="true" aria-expanded="false">' + title + ' <span class="caret"></span></a>');
#                         $newCmsContainer.append('<ul class="dropdown-menu dropdown-menu-sub"></ul>');
#                         $newCmsContainer.find('ul').append($childs);
#
#                         $this.remove();
#                     }
#                 }
#
#                 //CMS Mobile
#                 var $mobileCmsNavContainers = $("#ml-menu-container ul.cms-submenu div.cmsNavContainer");
#                 if ($mobileCmsNavContainers.length) {
#                     for (var i = 0; i < $mobileCmsNavContainers.length; i++) {
#                         var $this = $($mobileCmsNavContainers[i]);
#                         var $parentUl = $this.closest('ul.cms-submenu');
#
#                         $this.addClass('hidden');
#                         var thisTitle = $this.find('h3').html();
#                         var $thisChilds = $this.find('ul li');
#
#                         var dataMenu = $parentUl.attr('data-menu');
#                         var dataSubFor = $parentUl.attr('data-sub-for');
#
#                         $thisChilds.each(function () {
#                             $(this).addClass('menu__item');
#                             $(this).find('a').addClass('menu__link');
#                             $(this).find('a').attr('role', 'menuitem');
#                         });
#
#                         $thisChilds.appendTo($parentUl);
#                         $this.remove();
#
#                         var $subLinkAnchor = $("#ml-menu-container a.menu__link[data-submenu='submenu-cms-" + dataSubFor + "']");
#                         if ($subLinkAnchor.length) {
#                             $subLinkAnchor.html(thisTitle);
#                         }
#                     }
#                 }
#
#                 $('#mobile-navbar button[aria-expanded]').on('click', function () {
#                     var $this = $(this);
#                     var dataTargetMenuId = $this.attr('data-target-menu');
#                     var targetIsNavCollapsed = $('#' + dataTargetMenuId).hasClass('navbar-collapse');
#
#                     if (dataTargetMenuId != null && dataTargetMenuId != '') {
#                         setTimeout(function () {
#                             var menuIsOpen = false;
#                             if (targetIsNavCollapsed) {
#                                 menuIsOpen = $('#' + dataTargetMenuId).hasClass('collapse in');
#                             } else {
#                                 menuIsOpen = $('#' + dataTargetMenuId).hasClass('menu--open');
#                             }
#                             $this.attr('aria-expanded', menuIsOpen);
#                         }, 200);
#                     }
#                 });
#
#                 $('#jsrHeader .dropdown').children('.dropdown-toggle').on('click', function (e) {
#                     if ($(this).parent().is('.open')) {
#                         $(this).attr('aria-expanded', false);
#                     } else {
#                         $(this).attr('aria-expanded', true);
#                     }
#                 });
#                 $('#jsrHeader .dropdown-sub').children('.dropdown-toggle').on('click', function (e) {
#                     if ($(this).parent().is('.open')) {
#                         $(this).attr('aria-expanded', true);
#                     } else {
#                         $(this).attr('aria-expanded', false);
#                     }
#                 });
#
#                 var gHNInterval = setInterval(function () {
#                     if (typeof (globalHeaderNavigation) !== 'undefined') {
#                         clearInterval(gHNInterval);
#                         globalHeaderNavigation({"BreadcrumbAriaLabel":"Navigation Breadcrumb","InitialBreadcrumbText":"all"});
#                     }
#                 }, 20);
#
#             });
#         }
#
#         document.addEventListener("DOMContentLoaded", function (event) {
#
#             var isUsingAppDomainForServices = false;
#             if ('False' === 'True') {
#                 isUsingAppDomainForServices = true;
#             }
#
#             var hBarInterval = setInterval(function () {
#                 if (typeof (InitializeHeaderBarJsr) !== 'undefined') {
#                     clearInterval(hBarInterval);
#                     InitializeHeaderBarJsr(isUsingAppDomainForServices); // all header related script
#                 }
#             }, 20);
#
#                 AppendLocationMostPopularJobUrl();
#         });
#     </script>
# <script type="text/javascript">
#     function AppendLocationMostPopularJobUrl() {
#         var jsCritCookie = getCookie('jsCrit');
#         if (jsCritCookie === "" || jsCritCookie === null)
#             return;
#
#         var where = decodeURIComponent(getUrlVars(jsCritCookie)["where"]);
#         if (where === 'undefined' || where === "")
#             return;
#
#         var list = $('.dropdown-menu .dropdown-menu-sub').children();
#         $(list).each(function (index) {
#             var el = $(this).children().first()
#             var href = $(el).attr('href')
#             if (href.indexOf("?q=") >= 0) {
#                 $(el).attr("href", href + "&where=" + where);
#             }
#         })
#     }
#
#     function getCookie(cname) {
#         var name = cname + "=";
#         var decodedCookie = decodeURIComponent(document.cookie);
#         var ca = decodedCookie.split(';');
#         for (var i = 0; i < ca.length; i++) {
#             var c = ca[i];
#             while (c.charAt(0) == ' ') {
#                 c = c.substring(1);
#             }
#             if (c.indexOf(name) == 0) {
#                 return c.substring(name.length, c.length);
#             }
#         }
#         return "";
#     }
#
#     function getUrlVars(param) {
#         var vars = [], hash;
#         var hashes = param.split('&');
#         for (var i = 0; i < hashes.length; i++) {
#             hash = hashes[i].split('=');
#             vars.push(hash[0]);
#             vars[hash[0]] = hash[1];
#         }
#         return vars;
#     }
#
# </script>
# <script type="text/javascript">
#     window.addEventListener('load', function () {
#         var lbltypehint = document.getElementById('TypeHint');
#         if (lbltypehint != undefined && lbltypehint != null) {
#             lbltypehint.setAttribute('aria-label', 'Keywords');
#         }
#     });
# </script>
# <script type="text/javascript">
#             if (isMobile != undefined) {
#                 if (isMobile.any() != null && (getCookie('jobr.splitter.cookie') === "" || getCookie('jobr.splitter.cookie') === null)) {
#                     document.getElementById("jsrHeader").classList.add('showJobr');
#                     document.getElementsByTagName('body')[0].classList.add('has-jobr');
#                 }
#             }
#             var isMobile = {
#                 Android: function () {
#                     return navigator.userAgent.match(/Android/i);
#                 },
#                 BlackBerry: function () {
#                     return navigator.userAgent.match(/BlackBerry/i);
#                 },
#                 iOS: function () {
#                     return navigator.userAgent.match(/iPhone/i);
#                 },
#                 Opera: function () {
#                     return navigator.userAgent.match(/Opera Mini/i);
#                 },
#                 Windows: function () {
#                     return navigator.userAgent.match(/IEMobile/i);
#                 },
#                 any: function () {
#                     return (isMobile.Android() || isMobile.BlackBerry() || isMobile.iOS() || isMobile.Opera() || isMobile.Windows());
#                 }
#             };
#     </script>
# </div>
# <!--SecondaryNavigation-->
# <section class="mux-secondary-navigation">
# <div class="navigation-content">
# <span></span>
# <input id="filterSearchUrl" type="hidden" value="q=Programmer"/>
# <input id="evar63Json" type="hidden" value='{"company": [""],"category": [""],"kywdjobtitle": ["Programmer"],"location": ["Johnstown,Pennsylvania"],"skill": [""],"jobstatus": [""],"radius": ["20 miles"],"sort": [""],"date": [""],"country": [""],"salary": [""]}'/>
# <div class="mux-flyout mux-filter" id="filter-flyout">
# <button aria-expanded="false" aria-haspopup="true" class="mux-btn btn-link btn-neat flyout-toggle btn-mobile-nav" data-close="outside" data-dim-target="#mainContent" data-mux="dropdown" data-type="click" id="filter-flyout" role="button"><i aria-hidden="true" class="icon icon-settings"></i>Filter<i aria-hidden="true" class="icon icon-arrow-down"></i></button>
# <div aria-labelledby="filter-flyout" class="mux-card flyout-content" data-area="dropdown">
# <form action="#" class="card-content" data-mux="filter" data-target="#filter-flyout" id="filter-form" method="post">
# <header class="card-header flex-row">
# <h3 class="title">Filter your search</h3>
# <button class="mux-close" data-area="close" type="button">
# <i aria-hidden="true" class="icon icon-close"></i>
# <span class="sr-only">Close</span>
# </button>
# </header>
# <div class="row"> <div class="form-group col-sm-6">
# <label class="control-label" for="FilterRadius">Radius:</label>
# <select class="form-control" data-selector="radiusFilterDd" id="FilterRadius" name="FilterRadius" role="listbox">
# <option value="5">5 miles</option>
# <option value="10">10 miles</option>
# <option selected="" value="20">20 miles</option>
# <option value="30">30 miles</option>
# <option value="40">40 miles</option>
# <option value="50">50 miles</option>
# <option value="60">60 miles</option>
# <option value="75">75 miles</option>
# <option value="100">100 miles</option>
# <option value="150">150 miles</option>
# <option value="200">200 miles</option>
# </select>
# </div>
# <div class="form-group col-sm-6">
# <label class="control-label" for="FilterCity">Cities Nearby:</label>
# <select class="form-control" data-selector="cityFilterDd" id="FilterCity" name="FilterCity" role="listbox">
# <option value="">All Cities</option>
# <option selected="" value="india">Current location</option>
# </select>
# </div>
# </div><!--end row1--><div class="row"> <div class="form-group col-sm-6">
# <label class="control-label" for="FilterCompany">Company:</label>
# <select class="form-control" data-selector="companyFilterDd" id="FilterCompany" name="FilterCompany" role="listbox">
# <option value="">All Companies</option>
# <option value="cmpv=127864">Eagleview Technologies</option>
# <option value="cmpv=90331">Twilio Inc.</option>
# <option value="cmpv=8968">Decision Systems, Inc.</option>
# <option value="cmpv=122332">Spectrum Inc.</option>
# <option value="cmpv=29175">STATS, Inc.</option>
# </select>
# </div>
# <div class="form-group col-sm-6">
# <label class="control-label" for="FilterPosted">Date Posted:</label>
# <select class="form-control" data-selector="datePostedFilterDd" id="FilterPosted" name="FilterPosted" role="listbox">
# <option selected="" value="-1">
#                                                      Any date
#                                                  </option>
# <option value="0">
#                                                      Today
#                                                  </option>
# <option value="1">
#                                                      Yesterday
#                                                  </option>
# <option value="3">
#                                                      Last 3 days
#                                                  </option>
# <option value="7">
#                                                      Last 7 Days
#                                                  </option>
# <option value="14">
#                                                      Last 14 Days
#                                                  </option>
# <option value="30">
#                                                      Last 30 days
#                                                  </option>
# </select>
# </div>
# </div><!--end row1--><div class="row"> <div class="form-group col-sm-6">
# <label class="control-label" for="FilterJobStatus">Job Status:</label>
# <select class="form-control" data-selector="jbstFilterDd" id="FilterJobStatus" name="jbstFilterDd" role="listbox">
# <option value="">Select</option>
# <option value="Full-Time">Full Time</option>
# <option value="Part-Time">Part Time</option>
# </select>
# </div>
# </div><!--end row2-->
# <div class="form-actions">
# <button class="mux-btn btn-primary" id="use-filter-btn" type="submit">Submit</button>
# <button class="mux-btn btn-link" id="reset-filter-btn" type="reset">Reset Filter</button>
# </div>
# </form>
# </div>
# </div>
# <!--Recent Searches-->
# <div id="rspane">
# <input id="searchType" type="hidden" value="Power"/>
# <input id="enableNewJobsCount" type="hidden" value="True"/>
# <input id="lpfUrl" type="hidden" value="https://www.monster.com/jobs"/>
# <script type="text/javascript">
#         document.addEventListener("DOMContentLoaded", function (event) {
#             InitializeNewJobsCount();
#         });
#     </script>
# </div>
# <!--Titles-->
# <header class="title">
# <h1 class="pivot">
#                      Programmer Jobs in Johnstown, india
#                 </h1>
# <h2 class="figure">
#                         (38 Jobs Found)
#                     </h2>
# </header>
# <input id="isLoggedIn" type="hidden" value="false"/>
# <input id="maxSaveSearchesAllowed" type="hidden" value="5"/>
# <input id="emailUrl" type="hidden" value="https://www.monster.com/jobs/emailjobs?q=Programmer&amp;where=india"/>
# <div class="mux-flyout mux-job-alert" id="job-alert">
# <button aria-expanded="false" aria-haspopup="true" class="mux-btn btn-secondary flyout-toggle btn-mobile-nav" data-close="outside" data-mux="dropdown" data-type="click" id="job-alert-flyout" role="button">Create job alert</button>
# <div aria-labelledby="job-alert-flyout" class="mux-card flyout-content" data-area="dropdown">
# <section class="card-content">
# <header class="card-header flex-row">
# ...
# </a></h2>
# </header>
# <div class="company">
# <span class="name">Twilio</span>
# <ul class="list-inline">
# </ul>
# </div>
# <div class="location">
# <span class="name">
# Bangalore New York City Municipal Corporation Layout, Karnataka, KT
# </span>
# </div>
# </div>
# <div class="meta flex-col">
# <time datetime="2017-05-26T12:00
Programmer',''); clickJobTitleSiteCat('{&quot;events.event48&quot;:&quot;true&quot;,&quot;eVar25&quot;:&quot;Associate Development Manager&quot;,&quot;eVar66&quot;:&quot;Monster&quot;,&quot;eVar67&quot;:&quot;JSR2CW&quot;,&quot;eVar26&quot;:&quot;_International Decision Systems&quot;,&quot;eVar31&quot;:&quot;Bangaluru_KT_&quot;,&quot;prop24&quot;:&quot;2020-01-23T12:00&quot;,&quot;eVar53&quot;:&quot;1100055001001&quot;,&quot;eVar50&quot;:&quot;Aggregated&quot;,&quot;eVar74&quot;:&quot;regular&quot;}')">Associate Development Manager
# </a></h2>
# </header>
# <div class="company">
# <span class="name">International Decision Systems</span>
# <ul class="list-inline">
# </ul>
# </div>
# <div class="location">
# <span class="name">
# Bangaluru, KT
# </span>
# </div>
# </div>
# <div class="meta flex-col">
# <time datetime="2017-05-26T12:00">+30 days ago</time>
# <span class="mux-tooltip applied-only" data-mux="tooltip" title="Applied">
# <i aria-hidden="true" class="icon icon-applied"></i>
# <span class="sr-only">Applied</span>
# </span>
# <span class="mux-tooltip saved-only" data-mux="tooltip" title="Saved">
# <i aria-hidden="true" class="icon icon-saved"></i>
# <span class="sr-only">Saved</span>
# </span>
# </div>
# </div>
# </section>
# <section class="card-content" data-jobid="67320ef7-1234-4b88-91d7-6f9c84990633" onclick="MKImpressionTrackingMouseDownHijack(this, event)">
# <div class="flex-row">
# <div class="mux-company-logo thumbnail"></div>
# <div class="summary">
# <header class="card-header">
# <h2 class="title"><a data-bypass="true" data-m_impr_a_placement_id="JSR2CW" data-m_impr_j_cid="660" data-m_impr_j_coc="" data-m_impr_j_jawsid="433829510" data-m_impr_j_jobid="2178042" data-m_impr_j_jpm="2" data-m_impr_j_jpt="3" data-m_impr_j_lat="0" data-m_impr_j_lid="0" data-m_impr_j_long="0" data-m_impr_j_occid="11970" data-m_impr_j_p="25" data-m_impr_j_postingid="67320ef7-1234-4b88-91d7-6f9c84990633" data-m_impr_j_pvc="238a473f-f326-42d6-97e2-4fb4dd657137" data-m_impr_s_t="t" data-m_impr_uuid="ff982cfc-a44d-4344-9b0a-70d3cc65bc2b" href="https://job-openings.monster.com/data-engineer-bangalore-new-york-city-municipal-corporation-layout-karnataka-kt-us-twilio/67320ef7-1234-4b88-91d7-6f9c84990633" onclick="clickJobTitle('plid=0&amp;pcid=660&amp;poccid=11970','Programmer',''); clickJobTitleSiteCat('{&quot;events.event48&quot;:&quot;true&quot;,&quot;eVar25&quot;:&quot;Data Engineer&quot;,&quot;eVar66&quot;:&quot;Monster&quot;,&quot;eVar67&quot;:&quot;JSR2CW&quot;,&quot;eVar26&quot;:&quot;_Twilio&quot;,&quot;eVar31&quot;:&quot;Bangalore New York City Municipal Corporation Layout, Karnataka_KT_&quot;,&quot;prop24&quot;:&quot;2020-05-29T12:00&quot;,&quot;eVar53&quot;:&quot;1500127001001&quot;,&quot;eVar50&quot;:&quot;Aggregated&quot;,&quot;eVar74&quot;:&quot;regular&quot;}')">Data Engineer
# </a></h2>
# </header>
# <div class="company">
# <span class="name">Twilio</span>
# <ul class="list-inline">
# </ul>
# </div>
# <div class="location">
# <span class="name">
# Bangalore New York City Municipal Corporation Layout, Karnataka, KT
# </span>
# </div>
# </div>
# <div class="meta flex-col">
# <time datetime="2017-05-26T12:00">13 days ago</time>
# <span class="mux-tooltip applied-only" data-mux="tooltip" title="Applied">
# <i aria-hidden="true" class="icon icon-applied"></i>
# <span class="sr-only">Applied</span>
# </span>
# <span class="mux-tooltip saved-only" data-mux="tooltip" title="Saved">
# <i aria-hidden="true" class="icon icon-saved"></i>
# <span class="sr-only">Saved</span>
# </span>
# </div>
# </div>
# </section>
# </div>
# <a class="mux-btn btn-secondary load-more-btn" data-action="fetch" href="https://www.monster.com/jobs/search/?page=2" id="loadMoreJobs" role="button">Load more jobs</a>
# <a class="mux-btn btn-secondary no-more-jobs-btn disabled" id="noMoreResults" role="button" style="display:none">No More Results</a>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-8 detail-only">
# <div class="mux-custom-scroll mux-content-container" data-extend="right" data-mux="customScroll" id="ContentContainer">
# <div class="scrollable" id="ContentScrollable">
# <div class="mux-job-preview" data-apply-btn="#PrimaryJobApply" data-cloud-api-uri="//logs2.jobs.com" data-content-placeholder="job-preview-placeholder-template" data-content-template="job-preview-template" data-content-url="//job-openings.monster.com/v2/job/pure-json-view" data-email-btn="#emailFriendOpen" data-error-template="job-preview-error-template" data-messages-url="https://coda.newjobs.com/Assets/MUX/JaJobViewCloud/2020.05.0.765/msgset;MONS/app.jv30.ids" data-mux="jobPreview" data-offset-scroll="100" id="JobPreview"></div>
# <div class="mux-mobile-navigation" data-mux="mobileNavigation" data-source="#SearchResults"></div>
# <script id="FooterCustomScroll" type="text/x-placeholder"></script>
# </div>
# </div>
# </div>
# </div>
# <div class="dimmed-only"></div>
# </main>
# <footer class="mux-page-footer" data-breakpoints="md,lg" data-mux="cardResponsive" data-target="#FooterCustomScroll" id="PageFooter" role="contentinfo">
# <div class="footer-content">
# <a class="home" href="https://www.monster.com/"><i class="monster-logo-abbr"></i><span class="sr-only">CareerOne</span></a>
# <div class="legal-nav">
# <small class="copyright">Copyright © 2020 | Monster Worldwide </small>
# <small class="patents">U.S. Patents No. 7,599,930 B1; 7,827,125 and 7,836,060</small>
# <small class="affiliates"></small>
# </div>
# <div class="mux-a11y-switch">
# <input id="a11ySwitch" type="checkbox"/>
# <label class="toggle" data-mux="a11ySwitch" data-src="https://coda.newjobs.com/Assets/MUX/CoreLpf20/2020.04.0.174/css/app.lpf20.a11y.css https://coda.newjobs.com/Assets/MUX/JaJobViewCloud/2020.05.0.765/css/app.js30.a11y.css" data-text="Standard color version" for="a11ySwitch">
# <i class="icon icon-contrast"></i>
# <span class="label">High contrast version</span>
# </label>
# </div>
# </div>
# </footer>
# </div>
# <div class="hide">
# <script async="true" id="mww_icp_tracking" src="//media.newjobs.com/mm/rainbow/tracking/scripts/Icp/IdentityTracking.js?v=4554511" type="text/javascript"></script>
# <div style="display:none;"></div>
# </div>
# <script type="text/javascript">
#
#             var filename = 'https://coda.newjobs.com/Assets/MUX/JaJobViewCloud/2020.05.0.765/js/app.js30.bundle.js'.split('/').pop();
#             const asyncScriptsNodeList = document.querySelectorAll("script[src*='"+filename+"']");
#             var asyncScripts = Array.prototype.slice.call(asyncScriptsNodeList);
#             asyncScripts.forEach(function (sc) {
#                 sc.onload = function () {
#
#                     (function ($, d) {
#                         readyQ.forEach(function (f) {
#                             $(f);
#                         });
#                         bindReadyQ.forEach(function (f) {
#                             $(d).bind("ready", f);
#                         });
#                     })(jQuery, document);
#                     (function ($, w) {
#                         loadQ.forEach(function (f) {
#                             $(w).load(f);
#                         });
#                         bindLoadQ.forEach(function (f) {
#                             $(w).bind("load", f);
#                         });
#                     })(jQuery, window);
#                 }
#             });
#     </script>
# </body>
# </html>

# %%
results = soup.find(id='ResultsContainer')
print(results.prettify())
# Out:
# <div class="mux-custom-scroll" data-extend="left" data-mux="customScroll" data-target="html" id="ResultsContainer">
#  <div class="scrollable" id="ResultsScrollable">
#   <script type="application/ld+json">
#    {"@context":"https://schema.org","@type":"ItemList","mainEntityOfPage":{
#             "@type":"CollectionPage","@id":"https://www.monster.com/jobs/search/?q=Programmer&amp;where=india"
#             }
#             ,"itemListElement":[
#
#                  {"@type":"ListItem","position":1,"url":"https://job-openings.monster.com/software-developer-new-delhi-us-spectrum/578e82a3-5982-420e-b36e-bb5969068130"}
#                     ,
#                  {"@type":"ListItem","position":2,"url":""}
#                     ,
#                  {"@type":"ListItem","position":3,"url":"https://job-openings.monster.com/senior-software-engineer-computational-geometry-bengaluru-karnataka-bengaluru-kt-us-eagleview-technologies/f4add726-0553-421f-9342-68e6eed5bb6c"}
#                     ,
#                  {"@type":"ListItem","position":4,"url":"https://job-openings.monster.com/staff-software-engineer-backend-bengaluru-kt-us-lookout/48722ea9-4907-4340-aa7a-8f765a32d195"}
#                     ,
#                  {"@type":"ListItem","position":5,"url":"https://job-openings.monster.com/senior-software-developer-–-test-bangalore-kt-us-aurigo/a99f2454-2bab-4e2d-b30e-10e7d9ce0766"}
#                     ,
#                  {"@type":"ListItem","position":6,"url":"https://job-openings.monster.com/software-engineer-client-support-bengaluru-kt-us-international-decision-systems/6971e5fc-a816-48bb-b4c1-f3ebe9221359"}
#                     ,
#                  {"@type":"ListItem","position":7,"url":"https://job-openings.monster.com/software-engineer-outlook-plugin-banglore-kt-us-jobskey-consultancy/15969513-024d-446d-a038-5034f714290c"}
#                     ,
#                  {"@type":"ListItem","position":8,"url":""}
#                     ,
#                  {"@type":"ListItem","position":9,"url":"https://job-openings.monster.com/senior-software-engineer-bengaluru-karnataka-bengaluru-kt-us-stats/b13d3539-70c5-43a1-a3d8-6d38d668712c"}
#                     ,
#                  {"@type":"ListItem","position":10,"url":"https://job-openings.monster.com/software-engineer-ii-react-js-bengaluru-karnataka-bengaluru-kt-us-eagleview-technologies/a7ca1e8e-6f75-4909-b1ec-74a9e1a4e051"}
#                     ,
#                  {"@type":"ListItem","position":11,"url":"https://job-openings.monster.com/senior-software-developer-bangalore-kt-us-aurigo/96d77f46-d8fb-4fdb-814c-eceb3e6c0d75"}
#                     ,
#                  {"@type":"ListItem","position":12,"url":"https://job-openings.monster.com/software-engineer-bengaluru-karnataka-bengaluru-kt-us-stats/17069ec4-8360-4725-ba15-f07b8dff7954"}
#                     ,
#                  {"@type":"ListItem","position":13,"url":"https://job-openings.monster.com/senior-software-engineer-react-js-bengaluru-karnataka-bengaluru-kt-us-eagleview-technologies/886cef03-ec56-4ee1-8f9d-6c572ab967b0"}
#                     ,
#                  {"@type":"ListItem","position":14,"url":"https://job-openings.monster.com/web-developer-it-applications-sme-bangalore-kt-us-aurigo/a0921c3a-8714-4fe4-9df1-dc26c63f33ad"}
#                     ,
#                  {"@type":"ListItem","position":15,"url":"https://job-openings.monster.com/senior-software-engineer-iw-bengaluru-karnataka-bengaluru-kt-us-eagleview-technologies/709280d3-7353-4652-9b27-bb68bfbf7d00"}
#                     ,
#                  {"@type":"ListItem","position":16,"url":"https://job-openings.monster.com/software-engineer-ii-react-js-bengaluru-karnataka-bengaluru-kt-us-eagleview-technologies/4d8209b9-a48e-4ef7-ad98-84757560a724"}
#                     ,
#                  {"@type":"ListItem","position":17,"url":"https://job-openings.monster.com/senior-software-engineer-asp-net-bengaluru-karnataka-bengaluru-kt-us-eagleview-technologies/e0465566-a1d2-477c-aefd-6a21966c2f36"}
#                     ,
#                  {"@type":"ListItem","position":18,"url":"https://job-openings.monster.com/senior-software-engineer-backend-bengaluru-karnataka-bengaluru-kt-us-eagleview-technologies/54ac2ae8-54fc-42bb-97c3-bd34dc95cf06"}
#                     ,
#                  {"@type":"ListItem","position":19,"url":""}
#                     ,
#                  {"@type":"ListItem","position":20,"url":"https://job-openings.monster.com/software-architect-bengaluru-kt-us-international-decision-systems/61651f72-4e22-4efb-88b5-2db9a9d4a405"}
#                     ,
#                  {"@type":"ListItem","position":21,"url":"https://job-openings.monster.com/data-scientist-online-sales-new-delhi-us-spectrum/cc73f13b-0e63-4e3a-8383-c7154fa3f0fb"}
#                     ,
#                  {"@type":"ListItem","position":22,"url":"https://job-openings.monster.com/senior-principal-architect-–-product-engineering-bangalore-kt-us-aurigo/e525b16b-1f93-4337-ab04-0e76adcb0010"}
#                     ,
#                  {"@type":"ListItem","position":23,"url":"https://job-openings.monster.com/technical-support-engineer-bangalore-new-york-city-municipal-corporation-layout-karnataka-kt-us-twilio/e0c51a31-d2ad-4ed3-97b5-15ed664c7f79"}
#                     ,
#                  {"@type":"ListItem","position":24,"url":"https://job-openings.monster.com/hybris-designer-banglore-kt-us-jobskey-consultancy/48cd29bc-9f6f-4abd-9fce-ff7772b88c52"}
#                     ,
#                  {"@type":"ListItem","position":25,"url":"https://job-openings.monster.com/middleware-tech-lead-wso2-india-singapore-ny-us-compit-consultants/1c575afb-dd92-4747-b452-2ad85d3353ec"}
#                     ,
#                  {"@type":"ListItem","position":26,"url":"https://job-openings.monster.com/project-manager-bangalore-kt-us-aurigo/d575bdf4-c63b-4297-9913-7090c5736b63"}
#                     ,
#                  {"@type":"ListItem","position":27,"url":"https://job-openings.monster.com/associate-development-manager-bangaluru-kt-us-international-decision-systems/957e3257-d7dd-48f7-9794-947adc22af06"}
#                     ,
#                  {"@type":"ListItem","position":28,"url":"https://job-openings.monster.com/data-engineer-bangalore-new-york-city-municipal-corporation-layout-karnataka-kt-us-twilio/67320ef7-1234-4b88-91d7-6f9c84990633"}
#             ]}
#   </script>
#   <div class="mux-apas-ads" data-ads='[{"sizes":[1,1],"placementId":14162549,"id":"bad1"},{"sizes":[1,1],"placementId":14343737,"id":"bad2"},{"sizes":[728,90],"placementId":14343738,"id":"bad3"}]' data-config='{"targeting":{"Site":"United States","mURL":"https%3a%2f%2fwww.monster.com%2fjobs%2fsearch%2f%3fq%3dProgrammer%26where%3dindia","lid":"584","Page":"Job Search Results","mesco":[1500127001001,1700190001001]},"member":3525}' data-mux="apasAds">
#   </div>
#   <div class="mux-search-results" data-content-target="#JobPreview" data-emulated-click-attr="coretrackclickauto" data-is-dynamic="true" data-jhash-size="10" data-jhash-url="https://www.monster.com/jobs/search/jhpagination?q=Programmer&amp;where=india" data-jv-non-job-content="2" data-mux="searchResults" data-results-max="250" data-results-page="1" data-results-per-page="25" data-results-placeholder="job-item-placeholder-template" data-results-target="#SearchResults" data-results-template="job-item-template" data-results-total="38" data-results-url="https://www.monster.com/jobs/search/pagination/?q=Programmer&amp;where=india&amp;isDynamicPage=true&amp;isMKPagination=true" data-total-search-results="38">
#    <div class="mux-card mux-job-card" id="SearchResults">
#     <section class="card-content" data-jobid="578e82a3-5982-420e-b36e-bb5969068130" onclick="MKImpressionTrackingMouseDownHijack(this, event)">
#      <div class="flex-row">
#       <div class="mux-company-logo thumbnail">
#       </div>
#       <div class="summary">
#        <header class="card-header">
#         <h2 class="title">
#          <a data-bypass="true" data-m_impr_a_placement_id="JSR2CW" data-m_impr_j_cid="660" data-m_impr_j_coc="" data-m_impr_j_jawsid="434576425" data-m_impr_j_jobid="273389640" data-m_impr_j_jpm="1" data-m_impr_j_jpt="2" data-m_impr_j_lat="0" data-m_impr_j_lid="0" data-m_impr_j_long="0" data-m_impr_j_occid="11970" data-m_impr_j_p="1" data-m_impr_j_postingid="578e82a3-5982-420e-b36e-bb5969068130" data-m_impr_j_pvc="tmppx" data-m_impr_s_t="t" data-m_impr_uuid="d473a0a4-476d-4d41-ba08-18f22f1678f6" href="https://job-openings.monster.com/software-developer-new-delhi-us-spectrum/578e82a3-5982-420e-b36e-bb5969068130" onclick="clickJobTitle('plid=0&amp;pcid=660&amp;poccid=11970','Programmer',''); clickJobTitleSiteCat('{&quot;events.event48&quot;:&quot;true&quot;,&quot;eVar25&quot;:&quot;Software Developer&quot;,&quot;eVar66&quot;:&quot;Monster&quot;,&quot;eVar67&quot;:&quot;JSR2CW&quot;,&quot;eVar26&quot;:&quot;_SPECTRUM&quot;,&quot;eVar31&quot;:&quot;New Delhi__&quot;,&quot;prop24&quot;:&quot;2020-06-09T12:00&quot;,&quot;eVar53&quot;:&quot;1500127001001&quot;,&quot;eVar50&quot;:&quot;PPC&quot;,&quot;eVar74&quot;:&quot;regular&quot;}')">
#           Software Developer
#          </a>
#         </h2>
#        </header>
#        <div class="company">
#         <span class="name">
#          SPECTRUM
#         </span>
#         <ul class="list-inline">
#         </ul>
#        </div>
#        <div class="location">
#         <span class="name">
#          New Delhi
#         </span>
#        </div>
#       </div>
#       <div class="meta flex-col">
#        <time datetime="2017-05-26T12:00">
#         2 days ago
#        </time>
#        <span class="mux-tooltip applied-only" data-mux="tooltip" title="Applied">
#         <i aria-hidden="true" class="icon icon-applied">
#         </i>
#         <span class="sr-only">
#          Applied
#         </span>
#        </span>
#        <span class="mux-tooltip saved-only" data-mux="tooltip" title="Saved">
#         <i aria-hidden="true" class="icon icon-saved">
#         </i>
#         <span class="sr-only">
#          Saved
#         </span>
#        </span>
#       </div>
#      </div>
#     </section>
#     <section class="card-content apas-ad" data-mux="searchResultsAds" style="display:none">
#      <div id="bad1">
#      </div>
#     </section>
#     <section class="card-content" data-jobid="f4add726-0553-421f-9342-68e6eed5bb6c" onclick="MKImpressionTrackingMouseDownHijack(this, event)">
#      <div class="flex-row">
#       <div class="mux-company-logo thumbnail">
#       </div>
#       <div class="summary">
#        <header class="card-header">
#         <h2 class="title">
#          <a data-bypass="true" data-m_impr_a_placement_id="JSR2CW" data-m_impr_j_cid="660" data-m_impr_j_coc="" data-m_impr_j_jawsid="433948306" data-m_impr_j_jobid="511047" data-m_impr_j_jpm="2" data-m_impr_j_jpt="3" data-m_impr_j_lat="0" data-m_impr_j_lid="0" data-m_impr_j_long="0" data-m_impr_j_occid="11970" data-m_impr_j_p="2" data-m_impr_j_postingid="f4add726-0553-421f-9342-68e6eed5bb6c" data-m_impr_j_pvc="2d8ca3a0-0ee4-4c17-9972-791f51899eed" data-m_impr_s_t="t" data-m_impr_uuid="3caff5ed-7622-4fa8-957e-e06e958817a9" href="https://job-openings.monster.com/senior-software-engineer-computational-geometry-bengaluru-karnataka-bengaluru-kt-us-eagleview-technologies/f4add726-0553-421f-9342-68e6eed5bb6c" onclick="clickJobTitle('plid=0&amp;pcid=660&amp;poccid=11970','Programmer',''); clickJobTitleSiteCat('{&quot;events.event48&quot;:&quot;true&quot;,&quot;eVar25&quot;:&quot;Senior Software Engineer (Computational Geometry) - Bengaluru, Karnataka&quot;,&quot;eVar66&quot;:&quot;Monster&quot;,&quot;eVar67&quot;:&quot;JSR2CW&quot;,&quot;eVar26&quot;:&quot;_EagleView Technologies&quot;,&quot;eVar31&quot;:&quot;Bengaluru_KT_&quot;,&quot;prop24&quot;:&quot;2020-06-01T12:00&quot;,&quot;eVar53&quot;:&quot;1500127001001&quot;,&quot;eVar50&quot;:&quot;Aggregated&quot;,&quot;eVar74&quot;:&quot;regular&quot;}')">
#           Senior Software Engineer (Computational Geometry) - Bengaluru, Karnataka
#          </a>
#         </h2>
#        </header>
#        <div class="company">
#         <span class="name">
#          EagleView Technologies
#         </span>
#         <ul class="list-inline">
#         </ul>
#        </div>
#        <div class="location">
#         <span class="name">
#          Bengaluru, KT
#         </span>
#        </div>
#       </div>
#       <div class="meta flex-col">
#        <time datetime="2017-05-26T12:00">
#         10 days ago
#        </time>
#        <span class="mux-tooltip applied-only" data-mux="tooltip" title="Applied">
#         <i aria-hidden="true" class="icon icon-applied">
#         </i>
#         <span class="sr-only">
#          Applied
#         </span>
#        </span>
#        <span class="mux-tooltip saved-only" data-mux="tooltip" title="Saved">
#         <i aria-hidden="true" class="icon icon-saved">
#         </i>
#         <span class="sr-only">
#          Saved
#         </span>
#        </span>
#       </div>
#      </div>
#     </section>
#     <section class="card-content" data-jobid="48722ea9-4907-4340-aa7a-8f765a32d195" onclick="MKImpressionTrackingMouseDownHijack(this, event)">
#      <div class="flex-row">
#       <div class="mux-company-logo thumbnail">
#       </div>
#       <div class="summary">
#        <header class="card-header">
#         <h2 class="title">
#          <a data-bypass="true" data-m_impr_a_placement_id="JSR2CW" data-m_impr_j_cid="660" data-m_impr_j_coc="" data-m_impr_j_jawsid="431422298" data-m_impr_j_jobid="2176292" data-m_impr_j_jpm="2" data-m_impr_j_jpt="3" data-m_impr_j_lat="0" data-m_impr_j_lid="0" data-m_impr_j_long="0" data-m_impr_j_occid="11969" data-m_impr_j_p="3" data-m_impr_j_postingid="48722ea9-4907-4340-aa7a-8f765a32d195" data-m_impr_j_pvc="55d53362-5a12-46c6-b3d7-0087e37bfb26" data-m_impr_s_t="t" data-m_impr_uuid="0875376e-5f05-465f-b411-7c8f175ea2c4" href="https://job-openings.monster.com/staff-software-engineer-backend-bengaluru-kt-us-lookout/48722ea9-4907-4340-aa7a-8f765a32d195" onclick="clickJobTitle('plid=0&amp;pcid=660&amp;poccid=11969','Programmer',''); clickJobTitleSiteCat('{&quot;events.event48&quot;:&quot;true&quot;,&quot;eVar25&quot;:&quot;Staff Software Engineer- Backend&quot;,&quot;eVar66&quot;:&quot;Monster&quot;,&quot;eVar67&quot;:&quot;JSR2CW&quot;,&quot;eVar26&quot;:&quot;_Lookout&quot;,&quot;eVar31&quot;:&quot;Bengaluru_KT_&quot;,&quot;prop24&quot;:&quot;2020-05-22T12:00&quot;,&quot;eVar53&quot;:&quot;1500128001001&quot;,&quot;eVar50&quot;:&quot;Aggregated&quot;,&quot;eVar74&quot;:&quot;regular&quot;}')">
#           Staff Software Engineer- Backend
#          </a>
#         </h2>
#        </header>
#        <div class="company">
#         <span class="name">
#          Lookout
#         </span>
#         <ul class="list-inline">
#         </ul>
#        </div>
#        <div class="location">
#         <span class="name">
#          Bengaluru, KT
#         </span>
#        </div>
#       </div>
#       <div class="meta flex-col">
#        <time datetime="2017-05-26T12:00">
#         20 days ago
#        </time>
#        <span class="mux-tooltip applied-only" data-mux="tooltip" title="Applied">
#         <i aria-hidden="true" class="icon icon-applied">
#         </i>
#         <span class="sr-only">
#          Applied
#         </span>
#        </span>
#        <span class="mux-tooltip saved-only" data-mux="tooltip" title="Saved">
#         <i aria-hidden="true" class="icon icon-saved">
#         </i>
#         <span class="sr-only">
#          Saved
#         </span>
#        </span>
#       </div>
#      </div>
#     </section>
#     <section class="card-content" data-jobid="a99f2454-2bab-4e2d-b30e-10e7d9ce0766" onclick="MKImpressionTrackingMouseDownHijack(this, event)">
#      <div class="flex-row">
#       <div class="mux-company-logo thumbnail">
#       </div>
#       <div class="summary">
#        <header class="card-header">
#         <h2 class="title">
#          <a data-bypass="true" data-m_impr_a_placement_id="JSR2CW" data-m_impr_j_cid="660" data-m_impr_j_coc="" data-m_impr_j_jawsid="427553327" data-m_impr_j_jobid="13336784" data-m_impr_j_jpm="2" data-m_impr_j_jpt="3" data-m_impr_j_lat="0" data-m_impr_j_lid="0" data-m_impr_j_long="0" data-m_impr_j_occid="11970" data-m_impr_j_p="4" data-m_impr_j_postingid="a99f2454-2bab-4e2d-b30e-10e7d9ce0766" data-m_impr_j_pvc="cd3cee82-5073-4016-9f4a-d9b00b9d6481" data-m_impr_s_t="t" data-m_impr_uuid
Programmer',''); clickJobTitleSiteCat('{&quot;events.event48&quot;:&quot;true&quot;,&quot;eVar25&quot;:&quot;Middleware Tech Lead  (WSO2)&quot;,&quot;eVar66&quot;:&quot;Monster&quot;,&quot;eVar67&quot;:&quot;JSR2CW&quot;,&quot;eVar26&quot;:&quot;_COMPIT Consultants&quot;,&quot;eVar31&quot;:&quot;India/Singapore_NY_&quot;,&quot;prop24&quot;:&quot;2020-05-06T12:00&quot;,&quot;eVar53&quot;:&quot;1100011001001&quot;,&quot;eVar50&quot;:&quot;Aggregated&quot;,&quot;eVar74&quot;:&quot;regular&quot;}')">
#           Middleware Tech Lead  (WSO2)
#          </a>
#         </h2>
#        </header>
#        <div class="company">
#         <span class="name">
#          COMPIT Consultants
#         </span>
#         <ul class="list-inline">
#         </ul>
#        </div>
#        <div class="location">
#         <span class="name">
#          India/Singapore, NY
#         </span>
#        </div>
#       </div>
#       <div class="meta flex-col">
#        <time datetime="2017-05-26T12:00">
#         +30 days ago
#        </time>
#        <span class="mux-tooltip applied-only" data-mux="tooltip" title="Applied">
#         <i aria-hidden="true" class="icon icon-applied">
#         </i>
#         <span class="sr-only">
#          Applied
#         </span>
#        </span>
#        <span class="mux-tooltip saved-only" data-mux="tooltip" title="Saved">
#         <i aria-hidden="true" class="icon icon-saved">
#         </i>
#         <span class="sr-only">
#          Saved
#         </span>
#        </span>
#       </div>
#      </div>
#     </section>
#     <section class="card-content" data-jobid="d575bdf4-c63b-4297-9913-7090c5736b63" onclick="MKImpressionTrackingMouseDownHijack(this, event)">
#      <div class="flex-row">
#       <div class="mux-company-logo thumbnail">
#       </div>
#       <div class="summary">
#        <header class="card-header">
#         <h2 class="title">
#          <a data-bypass="true" data-m_impr_a_placement_id="JSR2CW" data-m_impr_j_cid="9008" data-m_impr_j_coc="" data-m_impr_j_jawsid="418713784" data-m_impr_j_jobid="11944237" data-m_impr_j_jpm="2" data-m_impr_j_jpt="3" data-m_impr_j_lat="0" data-m_impr_j_lid="0" data-m_impr_j_long="0" data-m_impr_j_occid="11934" data-m_impr_j_p="23" data-m_impr_j_postingid="d575bdf4-c63b-4297-9913-7090c5736b63" data-m_impr_j_pvc="cd3cee82-5073-4016-9f4a-d9b00b9d6481" data-m_impr_s_t="t" data-m_impr_uuid="b9946bd4-3949-43a1-9bf3-89fa40e1d9c4" href="https://job-openings.monster.com/project-manager-bangalore-kt-us-aurigo/d575bdf4-c63b-4297-9913-7090c5736b63" onclick="clickJobTitle('plid=0&amp;pcid=9008&amp;poccid=11934','Programmer',''); clickJobTitleSiteCat('{&quot;events.event48&quot;:&quot;true&quot;,&quot;eVar25&quot;:&quot;Project Manager&quot;,&quot;eVar66&quot;:&quot;Monster&quot;,&quot;eVar67&quot;:&quot;JSR2CW&quot;,&quot;eVar26&quot;:&quot;_Aurigo&quot;,&quot;eVar31&quot;:&quot;Bangalore_KT_&quot;,&quot;prop24&quot;:&quot;2020-02-15T12:00&quot;,&quot;eVar53&quot;:&quot;1300093001001&quot;,&quot;eVar50&quot;:&quot;Aggregated&quot;,&quot;eVar74&quot;:&quot;regular&quot;}')">
#           Project Manager
#          </a>
#         </h2>
#        </header>
#        <div class="company">
#         <span class="name">
#          Aurigo
#         </span>
#         <ul class="list-inline">
#         </ul>
#        </div>
#        <div class="location">
#         <span class="name">
#          Bangalore, KT
#         </span>
#        </div>
#       </div>
#       <div class="meta flex-col">
#        <time datetime="2017-05-26T12:00">
#         +30 days ago
#        </time>
#        <span class="mux-tooltip applied-only" data-mux="tooltip" title="Applied">
#         <i aria-hidden="true" class="icon icon-applied">
#         </i>
#         <span class="sr-only">
#          Applied
#         </span>
#        </span>
#        <span class="mux-tooltip saved-only" data-mux="tooltip" title="Saved">
#         <i aria-hidden="true" class="icon icon-saved">
#         </i>
#         <span class="sr-only">
#          Saved
#         </span>
#        </span>
#       </div>
#      </div>
#     </section>
#     <section class="card-content" data-jobid="957e3257-d7dd-48f7-9794-947adc22af06" onclick="MKImpressionTrackingMouseDownHijack(this, event)">
#      <div class="flex-row">
#       <div class="mux-company-logo thumbnail">
#       </div>
#       <div class="summary">
#        <header class="card-header">
#         <h2 class="title">
#          <a data-bypass="true" data-m_impr_a_placement_id="JSR2CW" data-m_impr_j_cid="3561" data-m_impr_j_coc="" data-m_impr_j_jawsid="418827947" data-m_impr_j_jobid="13130593" data-m_impr_j_jpm="2" data-m_impr_j_jpt="3" data-m_impr_j_lat="0" data-m_impr_j_lid="0" data-m_impr_j_long="0" data-m_impr_j_occid="11736" data-m_impr_j_p="24" data-m_impr_j_postingid="957e3257-d7dd-48f7-9794-947adc22af06" data-m_impr_j_pvc="beebb297-6551-48b6-9402-f820a922e02f" data-m_impr_s_t="t" data-m_impr_uuid="93050585-a66c-445c-ad60-ef5e914303ee" href="https://job-openings.monster.com/associate-development-manager-bangaluru-kt-us-international-decision-systems/957e3257-d7dd-48f7-9794-947adc22af06" onclick="clickJobTitle('plid=0&amp;pcid=3561&amp;poccid=11736','Programmer',''); clickJobTitleSiteCat('{&quot;events.event48&quot;:&quot;true&quot;,&quot;eVar25&quot;:&quot;Associate Development Manager&quot;,&quot;eVar66&quot;:&quot;Monster&quot;,&quot;eVar67&quot;:&quot;JSR2CW&quot;,&quot;eVar26&quot;:&quot;_International Decision Systems&quot;,&quot;eVar31&quot;:&quot;Bangaluru_KT_&quot;,&quot;prop24&quot;:&quot;2020-01-23T12:00&quot;,&quot;eVar53&quot;:&quot;1100055001001&quot;,&quot;eVar50&quot;:&quot;Aggregated&quot;,&quot;eVar74&quot;:&quot;regular&quot;}')">
#           Associate Development Manager
#          </a>
#         </h2>
#        </header>
#        <div class="company">
#         <span class="name">
#          International Decision Systems
#         </span>
#         <ul class="list-inline">
#         </ul>
#        </div>
#        <div class="location">
#         <span class="name">
#          Bangaluru, KT
#         </span>
#        </div>
#       </div>
#       <div class="meta flex-col">
#        <time datetime="2017-05-26T12:00">
#         +30 days ago
#        </time>
#        <span class="mux-tooltip applied-only" data-mux="tooltip" title="Applied">
#         <i aria-hidden="true" class="icon icon-applied">
#         </i>
#         <span class="sr-only">
#          Applied
#         </span>
#        </span>
#        <span class="mux-tooltip saved-only" data-mux="tooltip" title="Saved">
#         <i aria-hidden="true" class="icon icon-saved">
#         </i>
#         <span class="sr-only">
#          Saved
#         </span>
#        </span>
#       </div>
#      </div>
#     </section>
#     <section class="card-content" data-jobid="67320ef7-1234-4b88-91d7-6f9c84990633" onclick="MKImpressionTrackingMouseDownHijack(this, event)">
#      <div class="flex-row">
#       <div class="mux-company-logo thumbnail">
#       </div>
#       <div class="summary">
#        <header class="card-header">
#         <h2 class="title">
#          <a data-bypass="true" data-m_impr_a_placement_id="JSR2CW" data-m_impr_j_cid="660" data-m_impr_j_coc="" data-m_impr_j_jawsid="433829510" data-m_impr_j_jobid="2178042" data-m_impr_j_jpm="2" data-m_impr_j_jpt="3" data-m_impr_j_lat="0" data-m_impr_j_lid="0" data-m_impr_j_long="0" data-m_impr_j_occid="11970" data-m_impr_j_p="25" data-m_impr_j_postingid="67320ef7-1234-4b88-91d7-6f9c84990633" data-m_impr_j_pvc="238a473f-f326-42d6-97e2-4fb4dd657137" data-m_impr_s_t="t" data-m_impr_uuid="ff982cfc-a44d-4344-9b0a-70d3cc65bc2b" href="https://job-openings.monster.com/data-engineer-bangalore-new-york-city-municipal-corporation-layout-karnataka-kt-us-twilio/67320ef7-1234-4b88-91d7-6f9c84990633" onclick="clickJobTitle('plid=0&amp;pcid=660&amp;poccid=11970','Programmer',''); clickJobTitleSiteCat('{&quot;events.event48&quot;:&quot;true&quot;,&quot;eVar25&quot;:&quot;Data Engineer&quot;,&quot;eVar66&quot;:&quot;Monster&quot;,&quot;eVar67&quot;:&quot;JSR2CW&quot;,&quot;eVar26&quot;:&quot;_Twilio&quot;,&quot;eVar31&quot;:&quot;Bangalore New York City Municipal Corporation Layout, Karnataka_KT_&quot;,&quot;prop24&quot;:&quot;2020-05-29T12:00&quot;,&quot;eVar53&quot;:&quot;1500127001001&quot;,&quot;eVar50&quot;:&quot;Aggregated&quot;,&quot;eVar74&quot;:&quot;regular&quot;}')">
#           Data Engineer
#          </a>
#         </h2>
#        </header>
#        <div class="company">
#         <span class="name">
#          Twilio
#         </span>
#         <ul class="list-inline">
#         </ul>
#        </div>
#        <div class="location">
#         <span class="name">
#          Bangalore New York City Municipal Corporation Layout, Karnataka, KT
#         </span>
#        </div>
#       </div>
#       <div class="meta flex-col">
#        <time datetime="2017-05-26T12:00">
#         13 days ago
#        </time>
#        <span class="mux-tooltip applied-only" data-mux="tooltip" title="Applied">
#         <i aria-hidden="true" class="icon icon-applied">
#         </i>
#         <span class="sr-only">
#          Applied
#         </span>
#        </span>
#        <span class="mux-tooltip saved-only" data-mux="tooltip" title="Saved">
#         <i aria-hidden="true" class="icon icon-saved">
#         </i>
#         <span class="sr-only">
#          Saved
#         </span>
#        </span>
#       </div>
#      </div>
#     </section>
#    </div>
#    <a class="mux-btn btn-secondary load-more-btn" data-action="fetch" href="https://www.monster.com/jobs/search/?page=2" id="loadMoreJobs" role="button">
#     Load more jobs
#    </a>
#    <a class="mux-btn btn-secondary no-more-jobs-btn disabled" id="noMoreResults" role="button" style="display:none">
#     No More Results
#    </a>
#   </div>
#  </div>
# </div>

# %%
job_elems = results.find_all('section', class_='card-content')
job_elems
# Out:
# [<section class="card-content" data-jobid="578e82a3-5982-420e-b36e-bb5969068130" onclick="MKImpressionTrackingMouseDownHijack(this, event)">
#  <div class="flex-row">
#  <div class="mux-company-logo thumbnail"></div>
#  <div class="summary">
#  <header class="card-header">
#  <h2 class="title"><a data-bypass="true" data-m_impr_a_placement_id="JSR2CW" data-m_impr_j_cid="660" data-m_impr_j_coc="" data-m_impr_j_jawsid="434576425" data-m_impr_j_jobid="273389640" data-m_impr_j_jpm="1" data-m_impr_j_jpt="2" data-m_impr_j_lat="0" data-m_impr_j_lid="0" data-m_impr_j_long="0" data-m_impr_j_occid="11970" data-m_impr_j_p="1" data-m_impr_j_postingid="578e82a3-5982-420e-b36e-bb5969068130" data-m_impr_j_pvc="tmppx" data-m_impr_s_t="t" data-m_impr_uuid="d473a0a4-476d-4d41-ba08-18f22f1678f6" href="https://job-openings.monster.com/software-developer-new-delhi-us-spectrum/578e82a3-5982-420e-b36e-bb5969068130" onclick="clickJobTitle('plid=0&amp;pcid=660&amp;poccid=11970','Programmer',''); clickJobTitleSiteCat('{&quot;events.event48&quot;:&quot;true&quot;,&quot;eVar25&quot;:&quot;Software Developer&quot;,&quot;eVar66&quot;:&quot;Monster&quot;,&quot;eVar67&quot;:&quot;JSR2CW&quot;,&quot;eVar26&quot;:&quot;
onclick="clickJobTitle('plid=0&amp;pcid=660&amp;poccid=11970','Programmer',''); clickJobTitleSiteCat('{&quot;events.event48&quot;:&quot;true&quot;,&quot;eVar25&quot;:&quot;Data Engineer&quot;,&quot;eVar66&quot;:&quot;Monster&quot;,&quot;eVar67&quot;:&quot;JSR2CW&quot;,&quot;eVar26&quot;:&quot;_Twilio&quot;,&quot;eVar31&quot;:&quot;Bangalore New York City Municipal Corporation Layout, Karnataka_KT_&quot;,&quot;prop24&quot;:&quot;2020-05-29T12:00&quot;,&quot;eVar53&quot;:&quot;1500127001001&quot;,&quot;eVar50&quot;:&quot;Aggregated&quot;,&quot;eVar74&quot;:&quot;regular&quot;}')">Data Engineer
#  </a></h2>
#  </header>
#  <div class="company">
#  <span class="name">Twilio</span>
#  <ul class="list-inline">
#  </ul>
#  </div>
#  <div class="location">
#  <span class="name">
#  Bangalore New York City Municipal Corporation Layout, Karnataka, KT
#  </span>
#  </div>
#  </div>
#  <div class="meta flex-col">
#  <time datetime="2017-05-26T12:00">13 days ago</time>
#  <span class="mux-tooltip applied-only" data-mux="tooltip" title="Applied">
#  <i aria-hidden="true" class="icon icon-applied"></i>
#  <span class="sr-only">Applied</span>
#  </span>
#  <span class="mux-tooltip saved-only" data-mux="tooltip" title="Saved">
#  <i aria-hidden="true" class="icon icon-saved"></i>
#  <span class="sr-only">Saved</span>
#  </span>
#  </div>
#  </div>
#  </section>]

# %%
for job_elem in job_elems:
    title_elem = job_elem.find('h2', class_='title')
    company_elem = job_elem.find('div', class_='company')
    location_elem = job_elem.find('div', class_='location')
    if None in (title_elem, company_elem, location_elem):
        continue
    print(title_elem.text.strip())
    print(company_elem.text.strip())
    print(location_elem.text.strip())
    print()
# Out:
# Software Developer
# SPECTRUM
# New Delhi
#
# Senior Software Engineer (Computational Geometry) - Bengaluru, Karnataka
# EagleView Technologies
# Bengaluru, KT
#
# Staff Software Engineer- Backend
# Lookout
# Bengaluru, KT
#
# Senior Software Developer – Test
# Aurigo
# Bangalore, KT
#
# Software Engineer (Client Support )
# International Decision Systems
# Bengaluru, KT
#
# Software Engineer Outlook Plugin
# Jobskey Consultancy
# Banglore, KT
#
# Senior Software Engineer - Bengaluru, Karnataka
# STATS
# Bengaluru, KT
#
# Software Engineer II (React.js) - Bengaluru, Karnataka
# EagleView Technologies
# Bengaluru, KT
#
# Senior Software Developer
# Aurigo
# Bangalore, KT
#
# Software Engineer - Bengaluru, Karnataka
# STATS
# Bengaluru, KT
#
# Senior Software Engineer (React.js) - Bengaluru, Karnataka
# EagleView Technologies
# Bengaluru, KT
#
# Web Developer & IT Applications SME
# Aurigo
# Bangalore, KT
#
# Senior Software Engineer - IW - Bengaluru, Karnataka
# EagleView Technologies
# Bengaluru, KT
#
# Software Engineer II (React.js) - Bengaluru, Karnataka
# EagleView Technologies
# Bengaluru, KT
#
# Senior Software Engineer - Asp.net - Bengaluru, Karnataka
# EagleView Technologies
# Bengaluru, KT
#
# Senior Software Engineer (Backend) - Bengaluru, Karnataka
# EagleView Technologies
# Bengaluru, KT
#
# Software Architect
# International Decision Systems
# Bengaluru, KT
#
# Data Scientist - Online Sales
# SPECTRUM
# New Delhi
#
# Senior Principal Architect – Product Engineering
# Aurigo
# Bangalore, KT
#
# Technical Support Engineer
# Twilio
# Bangalore New York City Municipal Corporation Layout, Karnataka, KT
#
# Hybris Designer
# Jobskey Consultancy
# Banglore, KT
#
# Middleware Tech Lead  (WSO2)
# COMPIT Consultants
# India/Singapore, NY
#
# Project Manager
# Aurigo
# Bangalore, KT
#
# Associate Development Manager
# International Decision Systems
# Bangaluru, KT
#
# Data Engineer
# Twilio
# Bangalore New York City Municipal Corporation Layout, Karnataka, KT

# %%
jobs = results.find_all('h2', string='')
jobs
# Out:
# [<h2 class="title"><a data-bypass="true" data-m_impr_a_placement_id="JSR2CW" data-m_impr_j_cid="660" data-m_impr_j_coc="" data-m_impr_j_jawsid="434576425" data-m_impr_j_jobid="273389640" data-m_impr_j_jpm="1" data-m_impr_j_jpt="2" data-m_impr_j_lat="0" data-m_impr_j_lid="0" data-m_impr_j_long="0" data-m_impr_j_occid="11970" data-m_impr_j_p
data-m_impr_j_jpm="2" data-m_impr_j_jpt="3" data-m_impr_j_lat="0" data-m_impr_j_lid="0" data-m_impr_j_long="0" data-m_impr_j_occid="11934" data-m_impr_j_p="23" data-m_impr_j_postingid="d575bdf4-c63b-4297-9913-7090c5736b63" data-m_impr_j_pvc="cd3cee82-5073-4016-9f4a-d9b00b9d6481" data-m_impr_s_t="t" data-m_impr_uuid="b9946bd4-3949-43a1-9bf3-89fa40e1d9c4" href="https://job-openings.monster.com/project-manager-bangalore-kt-us-aurigo/d575bdf4-c63b-4297-9913-7090c5736b63" onclick="clickJobTitle('plid=0&amp;pcid=9008&amp;poccid=11934','Programmer',''); clickJobTitleSiteCat('{&quot;events.event48&quot;:&quot;true&quot;,&quot;eVar25&quot;:&quot;Project Manager&quot;,&quot;eVar66&quot;:&quot;Monster&quot;,&quot;eVar67&quot;:&quot;JSR2CW&quot;,&quot;eVar26&quot;:&quot;_Aurigo&quot;,&quot;eVar31&quot;:&quot;Bangalore_KT_&quot;,&quot;prop24&quot;:&quot;2020-02-15T12:00&quot;,&quot;eVar53&quot;:&quot;1300093001001&quot;,&quot;eVar50&quot;:&quot;Aggregated&quot;,&quot;eVar74&quot;:&quot;regular&quot;}')">Project Manager
#  </a></h2>,
#  <h2 class="title"><a data-bypass="true" data-m_impr_a_placement_id="JSR2CW" data-m_impr_j_cid="3561" data-m_impr_j_coc="" data-m_impr_j_jawsid="418827947" data-m_impr_j_jobid="13130593" data-m_impr_j_jpm="2" data-m_impr_j_jpt="3" data-m_impr_j_lat="0" data-m_impr_j_lid="0" data-m_impr_j_long="0" data-m_impr_j_occid="11736" data-m_impr_j_p="24" data-m_impr_j_postingid="957e3257-d7dd-48f7-9794-947adc22af06" data-m_impr_j_pvc="beebb297-6551-48b6-9402-f820a922e02f" data-m_impr_s_t="t" data-m_impr_uuid="93050585-a66c-445c-ad60-ef5e914303ee" href="https://job-openings.monster.com/associate-development-manager-bangaluru-kt-us-international-decision-systems/957e3257-d7dd-48f7-9794-947adc22af06" onclick="clickJobTitle('plid=0&amp;pcid=3561&amp;poccid=11736','Programmer',''); clickJobTitleSiteCat('{&quot;events.event48&quot;:&quot;true&quot;,&quot;eVar25&quot;:&quot;Associate Development Manager&quot;,&quot;eVar66&quot;:&quot;Monster&quot;,&quot;eVar67&quot;:&quot;JSR2CW&quot;,&quot;eVar26&quot;:&quot;_International Decision Systems&quot;,&quot;eVar31&quot;:&quot;Bangaluru_KT_&quot;,&quot;prop24&quot;:&quot;2020-01-23T12:00&quot;,&quot;eVar53&quot;:&quot;1100055001001&quot;,&quot;eVar50&quot;:&quot;Aggregated&quot;,&quot;eVar74&quot;:&quot;regular&quot;}')">Associate Development Manager
#  </a></h2>,
#  <h2 class="title"><a data-bypass="true" data-m_impr_a_placement_id="JSR2CW" data-m_impr_j_cid="660" data-m_impr_j_coc="" data-m_impr_j_jawsid="433829510" data-m_impr_j_jobid="2178042" data-m_impr_j_jpm="2" data-m_impr_j_jpt="3" data-m_impr_j_lat="0" data-m_impr_j_lid="0" data-m_impr_j_long="0" data-m_impr_j_occid="11970" data-m_impr_j_p="25" data-m_impr_j_postingid="67320ef7-1234-4b88-91d7-6f9c84990633" data-m_impr_j_pvc="238a473f-f326-42d6-97e2-4fb4dd657137" data-m_impr_s_t="t" data-m_impr_uuid="ff982cfc-a44d-4344-9b0a-70d3cc65bc2b" href="https://job-openings.monster.com/data-engineer-bangalore-new-york-city-municipal-corporation-layout-karnataka-kt-us-twilio/67320ef7-1234-4b88-91d7-6f9c84990633" onclick="clickJobTitle('plid=0&amp;pcid=660&amp;poccid=11970','Programmer',''); clickJobTitleSiteCat('{&quot;events.event48&quot;:&quot;true&quot;,&quot;eVar25&quot;:&quot;Data Engineer&quot;,&quot;eVar66&quot;:&quot;Monster&quot;,&quot;eVar67&quot;:&quot;JSR2CW&quot;,&quot;eVar26&quot;:&quot;_Twilio&quot;,&quot;eVar31&quot;:&quot;Bangalore New York City Municipal Corporation Layout, Karnataka_KT_&quot;,&quot;prop24&quot;:&quot;2020-05-29T12:00&quot;,&quot;eVar53&quot;:&quot;1500127001001&quot;,&quot;eVar50&quot;:&quot;Aggregated&quot;,&quot;eVar74&quot;:&quot;regular&quot;}')">Data Engineer
#  </a></h2>]

# %%
python_jobs = results.find_all('h2',string=lambda text: "react" in text.lower())

for p_job in python_jobs:
    link = p_job.find('a')['href']
    print(p_job.text.strip())
    print(f"Apply here: {link}\n")
# Out:
# Software Engineer II (React.js) - Bengaluru, Karnataka
# Apply here: https://job-openings.monster.com/software-engineer-ii-react-js-bengaluru-karnataka-bengaluru-kt-us-eagleview-technologies/a7ca1e8e-6f75-4909-b1ec-74a9e1a4e051
#
# Senior Software Engineer (React.js) - Bengaluru, Karnataka
# Apply here: https://job-openings.monster.com/senior-software-engineer-react-js-bengaluru-karnataka-bengaluru-kt-us-eagleview-technologies/886cef03-ec56-4ee1-8f9d-6c572ab967b0
#
# Software Engineer II (React.js) - Bengaluru, Karnataka
# Apply here: https://job-openings.monster.com/software-engineer-ii-react-js-bengaluru-karnataka-bengaluru-kt-us-eagleview-technologies/4d8209b9-a48e-4ef7-ad98-84757560a724
